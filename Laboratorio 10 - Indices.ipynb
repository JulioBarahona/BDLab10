# %% [markdown]
# ## Laboratorio 10 - Índices
#
# #### Bienvenida
#
# Este laboratorio tiene por objetivo verificar las mejoras en el desempeño de los queries en SQL cuando se trabajan los índices adecuados.
#
# Iniciaremos cargando la extensión de python que nos permitirá interactuar con bases de datos SQLite:

# %%
# %load_ext sql

# %% [markdown]
# Ejercicio 1
# ===========
#
# En este ejercicio trabajaremos con el dataset [consumer complaint database](https://catalog.data.gov/dataset/consumer-complaint-database) proveniente de from data.gov:

# %%
# %sql sqlite:///complaint.db
# Out:
# 'Connected: @complaint.db'

# %% [markdown]
# Adicionalmente utilizaremos una nueva extensión para poder estudiar los tiempos de respuesta de nuestros queries:

# %%
import time

# %% [markdown]
# Iniciemos verificando de qué datos disponemos en la base de datos.
#
# Escriba a continuación los queries necesarios para estudiar de qué tablas y atributos dispone en la base de datos:

# %%
# %sql SELECT * FROM sqlite_master;
# Out:
#  * sqlite:///complaint.db
# Done.
# [('table', 'complaints', 'complaints', 2, 'CREATE TABLE complaints(Date_received,Product,Subproduct,Issue,Subissue,\nConsumer_narrative,Company_public_response,Company,State,ZIP_code,Submitted_via,\nDate_sent_to_company,Company_response,Timely_response,\nConsumer_disputed,Complaint_ID)'),
#  ('table', 'sqlite_stat1', 'sqlite_stat1', 18222, 'CREATE TABLE sqlite_stat1(tbl,idx,stat)')]

# %% [markdown]
# ### (a) Queries sin índices (5 puntos)
#
# Escriba a continuación un query para encontrar el producto, estado y cantidad de complaints de los cinco pares (producto, estado) con la mayor cantidad de complaints.
#
# Utilice sintaxis de una sola linea de forma que pueda utilizar `%time` para estudiar el tiempo de ejecución:

# %%
# %time %sql SELECT Product,State,count(*) FROM complaints GROUP BY Product, State
# Out:
#  * sqlite:///complaint.db
# Done.
# Wall time: 172 ms
# [(None, None, 13451),
#  ('', None, 1),
#  ('', '01/01/2016', 1),
#  ('', '01/02/2016', 7),
#  ('', '01/03/2016', 9),
#  ('', '01/04/2016', 17),
#  ('', '01/05/2016', 16),
#  ('', '01/06/2016', 19),
#  ('', '01/07/2016', 26),
#  ('', '01/08/2016', 17),
#  ('', '01/09/2016', 6),
#  ('', '01/10/2016', 8),
#  ('', '01/11/2016', 23),
#  ('', '01/12/2016', 23),
#  ('', '01/13/2016', 17),
#  ('', '01/14/2016', 19),
#  ('', '01/15/2016', 25),
#  ('', '01/16/2016', 6),
#  ('', '01/17/2016', 8),
#  ('', '01/18/2016', 12),
#  ('', '01/19/2016', 12),
#  ('', '01/20/2016', 27),
#  ('', '01/21/2016', 22),
#  ('', '01/22/2016', 15),
#  ('', '01/23/2016', 6),
#  ('', '01/24/2016', 4),
#  ('', '01/25/2016', 10),
#  ('', '01/26/2016', 36),
#  ('', '01/27/2016', 29),
#  ('', '01/28/2016', 26),
#  ('', '01/29/2016', 19),
#  ('', '01/30/2016', 6),
#  ('', '01/31/2016', 4),
#  ('', '02/01/2016', 26),
#  ('', '02/02/2016', 20),
#  ('', '02/03/2016', 26),
#  ('', '02/04/2016', 22),
#  ('', '02/05/2016', 20),
#  ('', '02/06/2016', 12),
#  ('', '02/07/2016', 8),
#  ('', '02/08/2016', 16),
#  ('', '02/09/2016', 19),
#  ('', '02/10/2016', 25),
#  ('', '02/11/2016', 16),
#  ('', '02/12/2016', 24),
#  ('', '02/13/2016', 7),
#  ('', '02/14/2016', 9),
#  ('', '02/15/2016', 5),
#  ('', '02/16/2016', 13),
#  ('', '02/17/2016', 25),
#  ('', '02/18/2016', 33),
#  ('', '02/19/2016', 29),
#  ('', '02/20/2016', 10),
#  ('', '02/21/2016', 8),
#  ('', '02/22/2016', 26),
#  ('', '02/23/2016', 17),
#  ('', '02/24/2016', 31),
#  ('', '02/25/2016', 17),
#  ('', '02/26/2016', 24),
#  ('', '02/27/2016', 13),
#  ('', '02/28/2016', 6),
#  ('', '02/29/2016', 12),
#  ('', '03/01/2016', 29),
#  ('', '03/02/2016', 22),
#  ('', '03/03/2016', 20),
#  ('', '03/04/2016', 19),
#  ('', '03/05/2016', 11),
#  ('', '03/06/2016', 12),
#  ('', '03/07/2016', 17),
#  ('', '03/08/2016', 35),
#  ('', '03/09/2016', 22),
#  ('', '03/10/2016', 21),
#  ('', '03/11/2016', 22),
#  ('', '03/12/2016', 11),
#  ('', '03/13/2016', 7),
#  ('', '03/14/2016', 14),
#  ('', '03/15/2016', 27),
#  ('', '03/16/2016', 23),
#  ('', '03/17/2016', 21),
#  ('', '03/18/2016', 16),
#  ('', '03/19/2016', 7),
#  ('', '03/20/2016', 5),
#  ('', '03/21/2016', 19),
#  ('', '03/22/2016', 31),
#  ('', '03/23/2016', 20),
#  ('', '03/24/2015', 1),
#  ('', '03/24/2016', 21),
#  ('', '03/25/2016', 19),
#  ('', '03/26/2015', 1),
#  ('', '03/26/2016', 13),
#  ('', '03/27/2016', 3),
#  ('', '03/28/2016', 22),
#  ('', '03/29/2016', 26),
#  ('', '03/30/2016', 20),
#  ('', '03/31/2016', 10),
#  ('', '04/01/2015', 1),
#  ('', '04/01/2016', 25),
#  ('', '04/02/2016', 11),
#  ('', '04/03/2016', 10),
#  ('', '04/04/2016', 25),
#  ('', '04/05/2016', 25),
#  ('', '04/06/2016', 25),
#  ('', '04/07/2015', 1),
#  ('', '04/07/2016', 19),
#  ('', '04/08/2016', 24),
#  ('', '04/09/2016', 10),
#  ('', '04/10/2016', 3),
#  ('', '04/11/2016', 27),
#  ('', '04/12/2016', 30),
#  ('', '04/13/2015', 1),
#  ('', '04/13/2016', 22),
#  ('', '04/14/2016', 17),
#  ('', '04/15/2016', 20),
#  ('', '04/16/2015', 2),
#  ('', '04/16/2016', 6),
#  ('', '04/17/2016', 7),
#  ('', '04/18/2016', 18),
#  ('', '04/19/2016', 22),
#  ('', '04/20/2015', 1),
#  ('', '04/20/2016', 20),
#  ('', '04/21/2016', 21),
#  ('', '04/22/2016', 18),
#  ('', '04/23/2016', 9),
#  ('', '04/24/2016', 5),
#  ('', '04/25/2016', 13),
#  ('', '04/26/2016', 8),
#  ('', '04/27/2016', 23),
#  ('', '04/28/2016', 19),
#  ('', '04/29/2015', 1),
#  ('', '04/29/2016', 24),
#  ('', '04/30/2015', 1),
#  ('', '04/30/2016', 5),
#  ('', '05/01/2016', 5),
#  ('', '05/02/2016', 23),
#  ('', '05/03/2016', 26),
#  ('', '05/04/2016', 18),
#  ('', '05/05/2016', 21),
#  ('', '05/06/2016', 15),
#  ('', '05/07/2016', 2),
#  ('', '05/08/2016', 9),
#  ('', '05/09/2016', 17),
#  ('', '05/10/2016', 23),
#  ('', '05/11/2016', 20),
#  ('', '05/12/2015', 1),
#  ('', '05/12/2016', 14),
#  ('', '05/13/2016', 10),
#  ('', '05/14/2016', 12),
#  ('', '05/15/2015', 1),
#  ('', '05/15/2016', 1),
#  ('', '05/16/2016', 10),
#  ('', '05/17/2016', 7),
#  ('', '05/18/2016', 19),
#  ('', '05/19/2016', 10),
#  ('', '05/20/2015', 1),
#  ('', '05/20/2016', 8),
#  ('', '05/21/2016', 6),
#  ('', '05/22/2015', 1),
#  ('', '05/22/2016', 4),
#  ('', '05/23/2016', 12),
#  ('', '05/24/2016', 6),
#  ('', '05/25/2016', 8),
#  ('', '05/28/2015', 1),
#  ('', '06/03/2016', 1),
#  ('', '06/07/2016', 1),
#  ('', '06/10/2016', 1),
#  ('', '06/14/2016', 1),
#  ('', '06/15/2016', 2),
#  ('', '06/21/2016', 1),
#  ('', '06/24/2015', 1),
#  ('', '06/25/2015', 1),
#  ('', '06/30/2015', 1),
#  ('', '07/13/2015', 1),
#  ('', '07/14/2015', 1),
#  ('', '07/17/2015', 1),
#  ('', '08/08/2015', 1),
#  ('', '08/12/2015', 1),
#  ('', '09/02/2015', 1),
#  ('', '09/24/2015', 1),
#  ('', '09/30/2015', 1),
#  ('', '10/20/2015', 1),
#  ('', '10/27/2015', 1),
#  ('', '11/12/2015', 1),
#  ('', '11/18/2015', 1),
#  ('', '11/20/2015', 1),
#  ('', '12/02/2015', 8),
#  ('', '12/07/2015', 2),
#  ('', '12/08/2015', 15),
#  ('', '12/09/2015', 12),
#  ('', '12/11/2015', 1),
#  ('', '12/12/2015', 10),
#  ('', '12/13/2015', 7),
#  ('', '12/14/2015', 12),
#  ('', '12/15/2015', 14),
#  ('', '12/16/2015', 18),
#  ('', '12/17/2015', 9),
#  ('', '12/18/2015', 20),
#  ('', '12/19/2015', 3),
#  ('', '12/20/2015', 5),
#  ('', '12/21/2015', 16),
#  ('', '12/22/2015', 10),
#  ('', '12/23/2015', 14),
#  ('', '12/24/2015', 11),
#  ('', '12/26/2015', 5),
#  ('', '12/27/2015', 3),
#  ('', '12/28/2015', 19),
#  ('', '12/29/2015', 9),
#  ('', '12/30/2015', 12),
#  ('', '12/31/2015', 15),
#  ('', 'Consent not provided', 2),
#  ('  a TSYS Company"', 'Closed with explanation', 3),
#  ('  a TSYS Company"', 'Closed with monetary relief', 1),
#  (' "" ACCORDING TO THEIR SCHEDULE \'\'', None, 1),
#  (' "" Amount Due \'\' of : {$1100.00} XXXX XXXX', None, 1),
#  (' "" I understand you are upset because you were n\'t offered some sort of physician discount. \'\' Nope', None, 1),
#  (' "" Once the property is sold and the debt is paid', ' for servicing. Immediately after the financial meltdown of XXXX', 1),
#  (' "" Once your 90 day waiting period is complete', None, 1),
#  (' "" Our records indicate you have not made your last four or more regularly scheduled payments. Subject to applicable law', " we are offering you an opportunity to enter into a Trial Period for a loan modification ... '' I have in fact made payments for the entire time peri ... (156 characters truncated) ... merous Bank of America personnel in various departments ( See communication notes ) who transferred me back and forth between them with no resolution", 1),
#  (' "" They the agreed with PNC and are not changing the amount I owe. \'\' I also asked her to put how they came up with this agreement in writing and she said', 'Consent provided', 1),
#  (' "" Transactions should be processed in a neutral order that avoids manipulating or structuring processing order to maximize customer overdraft and related fees. Examples of a neutral order include order received', None, 1),
#  (' "" Which of these best describes your issue?', None, 1),
#  (' "" Who is XXXX? \'\' I asked him this because when the payments are taken out of my account my account shows the payments are going to a company named XXXX. XXXX XXXX told me his client was XXXX XXXX', None, 1),
#  (' "" XXXX XXXX', None, 1),
#  (' "" Yes. \'\' The man then said', ' "" No', 1),
#  (' "" Your creditor or debt collector believes that the legal time limit ( statute of limitations ) for suing you to collect this debt may have expired. It is a violation of the Fair Debt Collection Practices Act', None, 1),
#  (' "" how can a person who ca n\'t pay X', None, 1),
#  (' # XXXX', '705XX', 1),
#  (' # XXXX XXXX', None, 1),
#  (" '' 91 Stat. 874 ( XXXX )", 'OH', 1),
#  (" '' I do n't anticipate this complaint doing much good", None, 1),
#  (' \'\' and "" workout plans. \'\' We had made all of our payments on time. In another set of documents', ' we repeatedly called Bank of America for clarification', 1),
#  (" '' and my loan was magically put into forbearance. If the policy did in fact change the day after CFPB notified Wells Fargo of my complaint", None, 1),
#  (" '' and that they notified the other credit reporting agencies of the same information. I immediately called them", None, 1),
#  (' \'\' based ona "" range of potential losses for each matter that is both probable and estimable. \'\' Wells Fargo stated that the "" high end of the ... (12 characters truncated) ... asonably possible potential litigation losses in excess of the company \'s liability for probable and estimable losses was approximately {$1.00} XXXX', None, 1),
#  (" '' but when I asked why I never received a voice mail", None, 1),
#  (' \'\' or persons who furnish information to consumer reporting agencies ( "" CRA \'\' ) such as credit bureaus. In particular', None, 1),
#  (" '' that was purportedly signed by me", None, 1),
#  (" '' the CFPB said", None, 1),
#  (" '' which still leaves their prior negative information on my credit reports and negatively effects my credit scores. I was very specific in my request", None, 1),
#  (" 'executives ' are working on a lump sum settlement for all claims. Once a settlement is reached", ' a settlement', 1),
#  (' ( 6 months before it was due )', None, 1),
#  (' ( Credit Union ) response is that the information you have disputed is both true and correct according to all available documentation. As such', None, 1),
#  (' ( I was told that there was an issue with my expenses being too low and I was told that the underwriter took the initiative to calculate them at a higher amount even if they were not my actual expenses. ) XXXX XXXX', None, 1),
#  (' ( XXXX ) "" Seizures for Property \'\'', None, 1),
#  (' ( business plan', None, 1),
#  (' ( the settlement amount that I also have in canceled checks )', None, 1),
#  (' 1 week after yielding my physical address to AMEX', None, 1),
#  (' 12 CFR 226.15 ( b ) of Regulation Z states "" In any transaction or occurrence subject to rescission', None, 1),
#  (' 15 USC 1692', None, 1),
#  (' 2 months after closing my account and receiving a "" credit balance refund check. \'\' for {$2400.00} from them. May I please add that my account with them had a {$3000.00} CREDIT LIMIT! How can I possibly owe them {$600.00}?? Now my credit is being affected', None, 1),
#  (' 2013', None, 1),
#  (' 2015', None, 5),
#  (' 2015', 'Altisource Portfolio Solutions, S.à r.l.', 1),
#  (' 2015 ( relative to Nationstar/XXXX Notice of Debt Validation dated XX/XX/2015- with 30 day to validate debt ; then Nationstar violates FDCPA by recording the Notice of Default two days later', None, 1),
#  (' 2015 XXXX sent via email', None, 1),
#  (' 2015 by XXXX XXXX in XXXX', None, 1),
#  (' 2015 letter that FHA requires borrowers to provide a statement. I am providing documentation from FHA guidelines', None, 1),
#  (' 2015 not trying to validate the debt but to make a settlement offer', None, 1),
#  (" 2015 now through XXXX/XXXX/15. Rewards earned are in addition to your standard rewards and are added to your Miles account within 2 billing periods. ... (86 characters truncated) ... ged in deceptive marketing practices. They marketed a promotion promising amazing rewards with no cashback and after getting new customers to sign up", None, 1),
#  (' 2015 stating that I had to pay {$830.00} to cure the loan. Five days prior to the date of the letter I had already sent in a payment of {$820.00} via XXXX and then on XXXX XXXX', None, 1),
#  (' 2015. I provided a full written explanation and copies of the supporting evidence. As part of the investigation process', None, 1),
#  (' 2015. I think they are trying to collect for XXXX', None, 1),
#  (' 2015. The card has an annual fee of {$95.00} and it has an offer related to reimbursement of upto {$650.00} incurred towards purchase of new cellphone from AT & T provided new user spends {$2000.00} within 3 months. However', None, 1),
#  (' 2016', None, 7),
#  (' 2016 I contacted Commonwealth Financial Services to potentially pay off a debt. After talking with a lady who told me her name was XXXX XXXX we came ... (125 characters truncated) ... erification that the amount I was paying off was in writing. She emailed me XXXX verifications. I in return paid {$100.00} to settle a {$150.00} debt', None, 1),
#  (' 2016 I informed TD Bank that I was withdrawing my loan application due to their refusal to honor the terms of my original rate lock agreement. Due t ... (86 characters truncated) ... w lender I applied with sought an agreement to extend the deadline for the purchase and sales agreement between myself and the sellers. Unfortunately', None, 1),
#  (' 2016 I initiated an online dispute regarding the inaccurate reporting of inquiries and previous addresses on my Equifax file. Prior to that', None, 1),
#  (' 2016 I received a phone call stating that I received an {$8000.00} grant and in order to get the grant I had to give the account and routing number for my bank. The further instructions were to go to an ATM and pull out {$300.00}', None, 1),
#  (' 2016 I submitted a complaint to CFPB # XXXX "" Case number XXXX with response \'\'', None, 1),
#  (' 2016 I was notified on my online account that I was overdrawn. Knowing that I should have had funds I went online and checked and saw that Chase had reversed the credits from the dispute. This time instead of calling just the dispute center I called my local Chase Branch ( XXXX XXXX XXXX XXXX', None, 1),
#  (' 2016 TD Bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure indicated the correct loan', None, 1),
#  (' 2016 TD bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure again had the wrong terms', None, 1),
#  (' 2016 XXXX RESIDENT SCREENING Date : XXXX XXXX', ' 2016 XXXX XXXX XXXX Date : XXXX XXXX', 1),
#  (' 2016 are Attachments # XXXX "" BBVA XXXX XXXX XXXX letter-password reset \'\' and # XXXX "" BBVA deposit XX/XX/XXXX withdrawal XX/XX/2016.XXXX-balan ... (130 characters truncated) ...  Besides the absence of communication from the bank that results in lack of consumers knowledge of his account it shows contempt towards the customer', None, 1),
#  (" 2016. '' Recent phone calls from representative XXXX XXXX of the Collections Department of Navient Solutions ", None, 1),
#  (' 2016. \'\' Under the "" Address \'\' section of my "" Experian \'\' credit report it lists a false address of "" XXXX. XXXX XXXX ; XXXX', None, 1),
#  (' 2016. I have not received any documents."', 'Web', 1),
#  (' 3', None, 1),
#  (' 6 days after the XXXX due date. This meant that Wells Fargo \'s own process for refunding a payment that should have applied to XXXX would indeed ha ... (200 characters truncated) ... heir debts? I raised this question to the Wells Fargo staff who informed me this was "" just the way it is. \'\' To which I responded with skepticism', None, 1),
#  (' ALL INFORMATION OUTDATED SINCE 2005 AND ALL AGENCIES VIOLATES FCRA PROVISION XXXX', None, 1),
#  (" AND LACK OF GOOD FAITH IN YOUR DEALINGS WITH US AND OTHERS. ALL YOU EVER SEND TO US OR OUR STATE AND GOVERNMENT OFFICIAL 'S ARE OUR PAYMENT HISTORY", None, 1),
#  (' AND NEVER GOTTEN PROOF', None, 1),
#  (' ATTORNEY REPORTED MCCALLA RAYMER LLC WILL FILE SOMETHING CALLED CONTESTED MATTER TO RETURN TO COURT TO DISMM WHAT THEY CALL MOTION FOR RELIEF FROM A ... (192 characters truncated) ...  RELATED TO XXXX XXXX XXXX PAST XXXX AND MCALLA RAYMERS ASSOCIATES. CURRENTLY RECIEVING PREMISSION AND NOTARY STATEMENTS TO RELEASE THESE DOCUMENTS."', 'Web', 1),
#  (' Ally reposed the car from my mom place of residence. After the car was reposed by Ally', None, 1),
#  (' Alpha Recovery now has the debt and will not provide me with information nor have I been able to speak with someone who is reasonable and honest."', 'Web', 1),
#  (' Amazon', None, 1),
#  (" Amount Due '' of : {$1100.00}", None, 1),
#  (' Attorney -- -- -- -- -- -- -- -- -- -- -- -- -- - XXXX Virginia XXXX Office XXXX Mobile XXXX Mobile XXXX Email : XXXX XXXX ( Assistant ) -- -- -- -- -- -- -- -- - XXXX Non-Attorney Staff Member XXXX Virginia XXXX Office XXXX Fax XXXX"', 'Web', 1),
#  (' Attorney at Law', '02/05/2016', 1),
#  (' Authorized Representative', None, 1),
#  (' BANA has never merged with BofA Merrill Lynch Asset Holdings ', ' XXXX. CWHL', 1),
#  (' BB & T started adding additional fees to my note. They added the following fees : 1 ) {$1000.00} fee for XXXX appraisal fees -- why they would want  ... (64 characters truncated) ...  refinance is unexplainable. There is a provision in the contract that states if an appraisal is necessary I would be responsible for that fee. Again', None, 1),
#  (' BOA changed the property address to my XXXX home address and not my XXXX home address. The XXXX home is the collateral for a less than {$95000.00} modified equity line. In addition', None, 1),
#  (' BSI Financial Services', None, 1),
#  (' Bank of America. After a very frustrating process of them losing documents and re-asking for documents that I had already submitted', None, 1),
#  (' Barclaycard certified mail receipt and BarclaycardletterforACH ) because this account seems to have been confused and link to a bankruptcy that I fi ... (294 characters truncated) ... r pickup. I used the address provided by Barclay in the CFPB complaint response # XXXX at the bottom of their letter Card Services P.O. Box XXXX XXXX', None, 1),
#  (' Beal & Nixon', '02/25/2016', 1),
#  (' Bluebird XXXX XXXX XXXX XXXX XXXX XXXX', ' this bluebird account allows me to make deposits into my account easily but then they freeze my account every month while they verify everything."', 1),
#  (' BoA refuses to credit the {$38.00} because somewhere in a revised terms of service', None, 1),
#  (' BoA was never going to recoup the losses they assumed from Countrywide. As such', None, 1),
#  (' Branch Manager XXXX # XXXX HomeBridge Financial Services ', None, 1),
#  (' Burgess & Wolff', '12/21/2015', 1),
#  (" But did see on XXXX and all the inquires on Transunion credit. I know I have some outstanding debt. Probably close to XXXX with right XXXX price adj ... (449 characters truncated) ... t I would appreciate and cooperate in anyway for your help addressing these issues. Because I just do n't have the XXXX clarity to fight these issues", None, 1),
#  (' CA', None, 1),
#  (' CALIFORNIA XXXX TEL. NO ( XXXX ) XXXX', None, 1),
#  (' CMS guidelines also renders a loan ineligible to receive an alternative loan modification after receiving and defaulting under a HAMP Tier II TPP or a permanent HAMP Tier II loan modification under the same circumstances as outlined above. For this reason', None, 1),
#  (' Caliber Home Loans is and was', None, 1),
#  (' Case XXXX', None, 1),
#  (' Cash Advance Centers', '01/23/2016', 1),
#  (' Chase \'s counsel admitted that the denial was a "" streamline denial. \'\' She confirmed that the denial was not based on any information in the XXXX XXXX application because Chase had not actually reviewed it. The court directed that Chase review the XXXX XXXX application. On XXXX/XXXX/XXXX', None, 1),
#  (" Chase 's counsel emailed XXXX a letter denying XXXX for a Chase Modification", None, 1),
#  (' Chase XXXX', None, 1),
#  (' Chase did not correct the error', None, 1),
#  (' Chase was blaming the HOA first and', None, 1),
#  (" Citibank 's Illinois legal department refused the POA/XXXX submitted to the branch office. They instructed my cousin to call again or go to the XXXX XXXX in XXXX for notarization of there XXXX form", None, 1),
#  (' Citibank should be made to suffer the entire loss in the amount of {$1900.00}. Instead', None, 1),
#  (' Civil Code section 2923.5 requires lender to contact borrower in default and "" assess the borrower \'s financial situation and explore options for  ... (163 characters truncated) ...  CA. Homeowner Bill of Rights also provides that dual tracking protections can also protect homeowners who have been previously denied a modification', None, 1),
#  (' Complete and not in conflict with the account OPEN DATE and the CLOSURE DATE OR', None, 1),
#  (' Cruise and Smith LLC"', 'Untimely response', 1),
#  (' Customer Care 7 ) QUESTION FOR YOU : Am I not entitled to know how my bank uses ( lends or invests ) the money I deposit? Oil and gas is taking a huge hit right now and I want to know how my bank is exposed to losses. Is that not my right', None, 1),
#  (" DC also habitually charged late fees of {$39.00} even when I was n't late. I realize that they were doing this until after about a year of helping my mother-in-law when she passed away from XXXX. I called DC many times during my lunch break to have the late fees reimbursed. The refused. Finally", None, 1),
#  (" Debt collection agency. '' This is clearly confusing and misguiding consumers", None, 1),
#  (" Defendant 's principal place of businessis located at XXXX", None, 1),
#  (' Defendant filed a state court action againstPlaintiff on XXXX XXXX', None, 1),
#  (' Equifax ( r ) and XXXX ( r ) and any finance and other charges related to the fraudulent', None, 1),
#  (" Equifax is bounded in the terms set forth in the FCRA. Also let me remind you that under section 611 of the FCRA that you are required to investigate the completeness or accuracy of any item of information contained in a consumer 's file", None, 1),
#  (' Experian could not have conducted a reasonable reinvestigation to verify the accuracy of the disputed information. The FCRA clearly states that a cr ... (147 characters truncated) ... solely on hearsay information from the information source and shifted the burden back to me to contact the original creditor to verify these accounts', None, 1),
#  (' Experian has failed to complete their investigation within the 30-days', None, 1),
#  (' Experian has prevented Credit XXXX from getting my report and score. All info that I have provided to XXXX in XXXX has been exactly what I have given Experian when I obtained my free credit report today ( XXXX/XXXX/XXXX ). When I again tried CS today', None, 1),
#  (' Failed to show documentation that I have requested and failed to produce the note and Proof of Assignments to service my loan. XXXX also WILLINGLY and KNOWINGLY LIED ABOUT THE TRUSTEE AND OWNER OF THE NOTE by sending me the same LIE FILLED Note', None, 1),
#  (' Federal or CFPB guidelines. They think it is a joke."', 'Web', 1),
#  (' Florida has been contacted in each instance', None, 1),
#  (' From XXXX sent by wells Fargo in the year XXXX to us confirming the cancellation of this debt. Marked as XXXX ( This should have been done in the year XXXX and not in XXXX', None, 1),
#  (' GA XXXX \'\' Because the message is so vague ( "" a condition exists \'\' )', 'Consent provided', 1),
#  (' GA XXXX To whom it may concern : In accordance with Federal Civil Rights Law', None, 1),
#  (' GA XXXX"', 'Web', 1),
#  (' General Counsel for XXXX', ' legitimate cashier \'s checks bear the telephone number of the issuing institution ( which the counterfeit check did not ) and the check in question bore a suspicious "" security features box located on the reverse side. \'\' Therefore', 1),
#  (' Global Client Solutions', None, 1),
#  (' HSBC issued a response indicating the credit card account ending - XXXX is closed and that the credit will be deposited to my bank account. Please refer to Case number : XXXX. However', None, 1),
#  (' HUD', None, 1),
#  (" I 'm paraphrasing", None, 1),
#  (" I 'm sure you 'll want to handle this matter as soon as possible. For this purpose", None, 1),
#  (" I 've never had an XXXX account in my life but yet a debt of {$73.00} appears on my credit report", None, 1),
#  (" I 've resorted to filing this federal complaint due to the sinister organizational structure BofA has erected to try to get its customers to give up on collecting any checking account bonus due. I hope CFPB", None, 1),
#  (' I DEMAND ALL OF THEIR CLAIMS TO BE BACKED UP BY PRESENTING Convincing', None, 1),
#  (" I DEMAND that CHASE BANk 's credit reporting department", None, 1),
#  (' I HAVE TO GIVE UP THE RIGHT TO GO AFTER THE STOLEN MONEY AND LOOK FORWARD TO ONLY XXXX INSTEAD OF XXXX! BUT HOMELESS', None, 1),
#  (' I WAS DEFRAUDED BY BOTH THE VENDOR AND XXXX ... ... ..THE CREDIT REPORT DOES NOT CONTAIN A DOFD OF XX/XX/XXXX AS REQUIRED BY FCRA THE PAYMENT TABLE IS ERRONEOUS', ' WITH ME NOT PRESENT', 1),
#  (' I also bank here locally on the XXXX at XXXX bank. I keep my same old Chase bank account so I can send money to my grandmother who also banks there', ' the day my paycheck was projected to clear. That was the day Chase closed my account. As a result of the failed wire XXXX Checks I wrote bounced including the XXXX to court', 1),
#  (' I am', None, 1),
#  (" I am a victim of identity theft since XXXX 2015 and I have filed a police report for that submitting all evidences to the authorities. I have called ... (200 characters truncated) ...  have received a notice from my credit monitoring service that my credit score went down XXXX points in one shot! Checking my report to see the cause", None, 1),
#  (" I am away for the winter from the billing address and have not gotten Capital One 's last forwarded bill. However", None, 1),
#  (' I am disputing an account that I do not owe. The credit bureaus claimed the debt has been verified by IQ Data International. I call IQ Data Internat ... (67 characters truncated) ...  itemization. IQ data claims they do n\'t have it and could n\'t provide one anyways since they are not "" actively collecting the debt. \'\' However', None, 1),
#  (' I am furious', None, 1),
#  (' I am ineligible? That does not make any sense. It looks like a bait and switch to me."', 'Web', 1),
#  (' I am just shocked that Discover Card would treat a customer in this fashion. There is nothing "" negative \'\' that I have done wrong. Actually', None, 1),
#  (" I am just wondering why you do n't have an option for choosing what amount to pay in automatic payments", None, 1),
#  (' I am left with XXXX bank statement', ' after XXXX years later', 1),
#  (' I am more than happy to pay for the items', None, 1),
#  (' I am not refusing to pay', None, 1),
#  (' I am requesting disclosure of the "" original creditors documentation \'\'', 'Servicemember', 2),
#  (' I am seeking clarification as to how payments are to be handled', None, 1),
#  (' I am still waiting for them to submit the Verification of Mortgage to XXXX. I have been told they can only fax it to me', ' we are trying to make a college decision. I also will stop receiving child support the day he graduates. I do not think Citimortgage has the right to delay the process of the refinance. Their business practices are awful', 1),
#  (' I am trying to figure out what they told me they would not send it to collections and still did. and he responds stating the same thing : "" I will  ... (220 characters truncated) ...  lie about my issue to XXXX. I also complained to XXXX but they have done nothing but say they can only go off of email record and not over the phone', 'Consent provided', 1),
#  (' I am unable to log in and am unable to contact them', None, 1),
#  (' I am very bothered by how XXXX has conducted business', None, 1),
#  (' I and about 10-15 other students sued the XXXX XXXX XXXX XXXX for breach of contract after finding out the XXXX XXXX XXXX XXXX said on average', None, 1),
#  (' I applied for the new card on-line', None, 1),
#  (' I applied to refinance my home loan and my credit score was crucial to obtaining an affordable loan for the next 30 years of my life! After the loan ... (161 characters truncated) ...  score and the debt to income ratio in a big way. I called Citibank XXXX customer service to see what it meant as my online hub showed NO payment due', ' what does that mean? And then was why there was a $ XXXX payment due but my Citibank hub showed no payment due? After much talking she got me togeth ... (28 characters truncated) ... nd I explained they pulled my credit WITHOUT my permission and to listen to my conversations. She tried to get me to the manager but no one picked up', 1),
#  (' I ask numerous of time', None, 1),
#  (' I asked Bank to reimburse me', None, 1),
#  (' I asked XXXX who at the bank makes the decision and he told me the Underwriters at US Bank makes the decisions. I asked him if I could speak with them to find out what factors decided the definitive yes or no to a business loan', None, 1),
#  (' I asked her to spell her name and she said in a very sarcastic way "" XXXX', 'Company believes complaint represents an opportunity for improvement to better serve consumers', 1),
#  (' I asked how to file and was told send a copy to their office', None, 1),
#  (' I asked if she had pulled calls from around that time frame as I had requested. She stated no', 'Consent provided', 1),
#  (' I asked my wife', " I finally got XXXX XXXX on the telephone ; he first stated he could not speak with me because my name was not on the checking account. I reminded hi ... (62 characters truncated) ... ly said he would probably mail it. I told him it was close to XXXX and we needed the check to do what needed to be done. He did n't say anything else", 1),
#  (' I asked them to provide the refinance paperwork ; however', None, 1),
#  (' I attempted to make several arrangements to catch up but fell short. As a result of that', None, 1),
#  (" I become ineligible for a HARP. '' If there is documentation stating the aforementioned quote", None, 1),
#  (' I began receiving calls again from WFDS', None, 1),
#  (' I believe that essential information about simple ground rules of the modification process were kept from me. I also believe that serious delays caused by the bank which inflated the amount of the loan over the years is not being considered by the underwriters. And finally', None, 1),
#  (' I believe this account is invalid because any original creditor that I had a balance with years ago', None, 1),
#  (' I believe this to be an unlawful attempt to extort funds from me', None, 1),
#  (' I called Honda back and asked again for help so I can keep my vehicle', None, 1),
#  (' I called XXXX directly again on XXXX/XXXX/16. I was told voice messages were left notifying me of the late payments', None, 1),
#  (' I called and filed for claim for XXXX out XXXX transactions cleared in bank statement. On XXXX/XXXX/2016', None, 1),
#  (' I called and submitted a call back request. I had to call XXXX additional times time to get a status update. Each time I was given a different time frame for the transaction refund ( XXXX biz days', None, 1),
#  (' I called back at XXXX and told them I have already spoken to them this week and that I will not have a different answer than what I have already giv ... (265 characters truncated) ... redit Services Inc ( XXXX ) @ XXXX I get a call and voicemail from XXXX XXXX at Sunrise Credit Services Inc . I call back @ XXXX and speak with XXXX ', None, 1),
#  (' I called customer service. They were helpful at first ... but promised action which they never delivered. ( For example', None, 1),
#  (' I called the Amazon Credit Card / Synchrony bank and managed to get my account number. While on the phone', None, 1),
#  (' I called them', None, 1),
#  (' I called to inquire about the replacement refund check. I again spoke to XXXX who told me that early in the month', None, 1),
#  (' I called to set up payment arrangements and speedy cash told me my account has went over to a third party collection agency. They also provided me with XXXX. I never provided them with my debit card from XXXX XXXX information. However', None, 1),
#  (' I can call many times if i get a busy or no answer but if I talk to a debtor to make a demand I really should not all XXXX times in a day. If I did not have money at XXXX', None, 1),
#  (' I can not believe that this shift in standards is a misunderstanding or an error made in good faith. When I raised the concern initially', None, 1),
#  (' I can not pay them', None, 1),
#  (' I can only lodge a complaint by phone. To prevent further charges to my account and because of my inability to reach BOA', None, 1),
#  (' I can see that she is only interested in having me pay money', 'First Advantage LNS Inc.', 1),
#  (' I checked in to be sure the miles would be posted as promised', None, 1),
#  (' I checked my FICO score and it was XXXX. Within one week ( today )', None, 2),
#  (' I checked my balance online and saw that all the XXXX transactions were pending', ' and found that the TCF ATM does not take deposits. The nearest branch is XXXX miles from my home', 1),
#  (" I contacted Wells Fargo 's agents advising them of my struggles to keep up with my mortgage payments. Wells Fargo 's agents offered me an opportunit ... (55 characters truncated) ... eparate loan modification packages. After what seemed like the run around and paper chase with agents requesting and re-requesting the same documents", None, 1),
#  (' I contacted customer service again', ' which to date', 1),
#  (' I contacted my bank', ' including a letter from the garage in XXXX that verified the work done in XXXX was not what I requested', 1),
#  (" I contacted the State 's Attorney General 's Office in XXXX", None, 1),
#  (' I continued to pursue my case and finally', ' no one is held accountable for his promise. In fact', 1),
#  (' I could not log on answering the questions as myself. I tried again about XXXX hour later and XXXX of the XXXX questions were geared for my sister in law', ' which is what SHE owns', 1),
#  (' I decided to send money to people on my mailing address for them to send me the card that arrived on XXXX. When they are ready to send', None, 1),
#  (" I demand to see Assignments. A major crime has been committed and It is very Obvious that they 've tried to Manipulate me and the legal System as we ... (84 characters truncated) ... nipulate CFPB as well. These XXXX companies are CRIMINALS and Have Many Fraud Complaints and Lawsuits Filed against them. By checking CFPB site alone", None, 1),
#  (' I did', None, 1),
#  (' I did my due diligence to protect myself and wished that PNC did the same for its cardholder."', 'Web', 1),
#  (' I did my research and found numerous complaints about this company as well as a news piece by investigative reporter "" XXXX XXXX \'\' that aired XXXX 2012 : XXXX"', 'Web', 1),
#  (' I did not feel comfortable. At this point', None, 1),
#  (' I discovered in 2015 that I am the victim of major identity theft. If someone opened up a fraudulent account with CitiBank', None, 1),
#  (" I do n't remember. I complete XXXX loan applications a month ''. At that time", None, 1),
#  (' I do not know what this account is nor did I ever sign any documentation with this company. I have disputed it several times and as you can see the  ... (91 characters truncated) ... ' this issue was never resolved? I received no validation documentation of what this is nor where my signature is nor that this account belongs to me', None, 1),
#  (' I entered my credit card number and it came back to me with', None, 1),
#  (' I eventually conducted a three way phone call with XXXX regional supervisor and a TD Bank supervisor. During the call', None, 1),
#  (' I expect that all adverse information will be withdrawn from the credit records of XXXX XXXX XXXX immediately. In the event such adverse information is not withdrawn', None, 1),
#  (" I expected my PayPal balance to reflect the cancellation quickly. It did n't. I finally got a XXXX rep with enough skills to get me the XXXX phone number and information. The information was that I needed to get PayPal support on the phone and conference in XXXX. XXXX confirmed on the phone", ' not theirs at all."', 1),
#  (' I explained myself again and he said I had the following options and I quote ; "" Make the payment in full', None, 1),
#  (' I explained that I never knew I had a debt and certainly would have worked this out with the hospital', ' I do the same thing', 1),
#  (' I faxed this written statement to the number provided. On XXXX/XXXX/16', None, 1),
#  (' I feel as though XXXX XXXX XXXX', ' have some of my debt removed and my credit cleaned up. I was young', 1),
#  (' I feel it is BAD PRACTICE for Capital One to not put SOMETHING', None, 1),
#  (' I feel like somewhere I received some bad student loan advice and possibly made some errors along the way. XXXX University in XXXX', ' however. The XXXX University Financial Aid Office was horrifically inept and even though I regularly tried to contact them', 1),
#  (' I feel sure this is a scam', None, 1),
#  (" I filed a inquiry to XXXX to clarify what had happened and to ask for a refund. On XXXX/XXXX/16 I received this response : I 'm sorry if the fee was ... (53 characters truncated) ...  certainly research if this is an issue on our end or deluxe. You may return the checks to your nearest branch at usbank.com/locations. In the future", None, 1),
#  (' I finally got a human on the line. She sounded XXXX and did not grasp that this was a fraudulent use of my account until I pointed that out to her. She said she would get the charges removed from my account and would also cancel it', None, 1),
#  (' I finally got the funds on Thursday', None, 1),
#  (' I first purchased my home by signing a home loan with XXXX and was immediately transferred to Wells Fargo Bank. I paid my mortgage as agreed on time for years. However', None, 1),
#  (' I followed further instructions from my supposed new employer to send XXXX wire transfers for {$800.00} and {$900.00} to XXXX', 'CA', 1),
#  (' I forgot to cancel the service prior to it converting into a recurrent billing subscription. After noticing the charges a month or two later I conta ... (138 characters truncated) ... acted them again and when that did not work I closed my bank account and opened a new account to prevent any further unscrupulous charges. Last night', ' requesting a cancellation payments have always stopped so I have never needed to ever call Paypal with a problem. Needless to say', 1),
#  (' I found that Discover had a department called the "" Executive Office of Customer Advocacy. \'\' I thought this dept would handle my concern in a more "" independent \'\' manner', None, 1),
#  (' I found the XXXX XXXX XXXX XXXX \'Welcome Letter \' mixed in with some junk mail that was sitting on my office desk - I was in the process of accumulating various numbers for my XXXX Tax return."', 'Web', 1),
#  (' I got an alert ( Through an ID monitoring service ) that my credit report had a hard inquiry twice', None, 1),
#  (' I guess to prevent customer complaints. And it is not working for many days now', 'Consent provided', 1),
#  (' I had 9 months before that was to begin. RMS has made a complete mess out of this seemingly easy transaction and with no legal oversight by state and federal regulators', None, 1),
#  (' I had approximately 15 months remaining on my business locations lease and certainly informed him of that fact. I also mentioned that I wanted to save approximately XXXX dollars per month with any new agreement', None, 1),
#  (' I had come to find out this had happened again when Sallie Mae was asking for the upcoming XXXX payment. I called Sallie Mae to figure out what was  ... (198 characters truncated) ...  I then asked that enough money be taken out of the overflow account to pay for any outstanding payments ( XXXX and XXXX payments ) for the XXXX loan', None, 1),
#  (' I had defaulted on XXXX my smaller loans. The loan did get paid off but this has effected my credit score as well as my parents and when trying to t ... (308 characters truncated) ... . When asked if the terms could be changed or allowed for my cosigner parents to be released from my loans after so many consecutive on time payments', None, 1),
#  (' I had exceptional credit score', None, 1),
#  (' I had gone into a Chase bank branch and followed instructions to withdraw my cash from my checking/savings account', None, 1),
#  (' I had made XXXX successful payments on time with this current loan', None, 1),
#  (' I had some extraordinarily large bills to pay. Car registration', ' threatening letter from a XXXX XXXX', 1),
#  (" I had to cancel that dispute. It will come out of my account tomorrow and I 'll be negative", None, 1),
#  (' I had to verify the last XXXX of my SS. Then the man ( XXXX XXXX ) said I took out a payday loan in XXXX 2013 from XXXX XXXX', '782XX', 1),
#  (' I have XXXX requests. First', None, 1),
#  (' I have also been inundated with emails from Western Union and others. If I recall', None, 1),
#  (' I have asked among other things in my day XXXX/XXXX/XXXX dispute a copy of the contract signed by my accepting the terms and conditions of these bills and my obligation to pay a bill it is not proof of debt', ' any document without my signature lacks validity', 1),
#  (' I have asked and told them to STOP calling me', None, 1),
#  (' I have asked time and time again for account loan data from original lender and the debt collector refused yet they are continuing to threaten to st ... (98 characters truncated) ... ing further injury to me and my family. Altisource has called me numerous times and has called relatives and discussed with them our private business', 'Consent provided', 1),
#  (' I have been asking for my Mortgage Loan review for the past one year now', None, 1),
#  (' I have been communicating on many occasions about issues with payment transaction issues. Each and every time I have communicated with your organization', None, 1),
#  (" I have been denied access to speak directly to the CITIBANK 'S legal department and have been", None, 1),
#  (' I have been depleting what little retirement I had from my Mutual funds and IRA to be able to meet living expenses. At this rate', None, 1),
#  (" I have been paying extra on my car loan since we purchase the car in XXXX XXXX XXXX XXXX. The question I have is my payment is XXXX and my loan paym ... (296 characters truncated) ...  will credit XXXX out of a payment of XXXX and the answer is they carry that overpayment forward and I ask why do n't they apply some to the interest", None, 1),
#  (' I have cried', None, 1),
#  (' I have enclosed the XXXX Cancelling the debt. Please delete this account XXXX XXXX', None, 1),
#  (' I have finally had an opportunity to speak with XXXX and get to the increase in closing costs. Our initial interview was on XXXX/XXXX/XXXX. At that time I was calculating the Tax Transfer Fee to be a common and customary fee 100 % paid by for by the seller. XX/XX/XXXX', None, 1),
#  (" I have n't received a letter", None, 1),
#  (" I have never been given any kind of credit unless I asked for it and filled out a credit application. How can PayPal be allowed to get away with this scam? I 've been using PayPal for years. If they 've done something to their check out process to make PayPal Credit the default", None, 1),
#  (' I have never heard from any of them. I will attach the docs that show the tax releases. I hope you can help me', None, 1),
#  (' I have no obligation to XXXX since XXXX lnXXXX', ' her pay was reduced. XXXX staff advised that we could restructure the loan slightly so she could make payments. I helped her with several payments as we waited for XXXX to work with us. Rather suddenly', 1),
#  (' I have no other choice that make my complaint more public and request escalation on this case."', 'Web', 1),
#  (' I have proven your records are inaccurate compared to the financial institution transactions', None, 1),
#  (' I have received XXXX calls', None, 1),
#  (' I have received XXXX curb appraisals from Wells Fargo Bank', ' XXXX Wells Fargo sent out a 30 day notice to pay my past due amounts owed', 1),
#  (' I have received over 50 calls from this number XXXX. When I pick up the phone', None, 1),
#  (' I have requested a complete detailed explanation of the current deficiency which has gone unanswered. I believe the current monthly payment is also incorrect and does not reflect the terms in both the Truth in Lending Statement as well as the actual terms of the Adjustable Rate Note."', 'Web', 1),
#  (" I have searched the Federal Housing Administration 's ( FHA ) website", None, 1),
#  (' I have shared my bank statement ( attached ) showing the XXXX {$200.00} transactions and XXXX {$100.00} transactions as well as the recovery of XXXX ... (60 characters truncated) ... t in their system they showed XXXX {$200.00} transactions on XXXX however their system rejected XXXX {$200.00} payment and it went back to the source', None, 1),
#  (" I have since I was XXXX I 'm now XXXX the close of escrow is XXXX - this house was the perfect house for my husband who is XXXX", None, 1),
#  (' I have since put a stop payment on all my automatic-bill transactions', ' when all I had to do was give the bank what I actually owe them', 1),
#  (' I have spoken to several Barclay representatives', None, 1),
#  (' I have submitted information to remove the XXXX addresses that are not associated with me', None, 1),
#  (' I have tried to contact them directly and through the Credit Bureau', None, 1),
#  (' I have tried working out payments with Navient', None, 1),
#  (' I have without fail made monthly and timely in-person payments on both accounts', ' despite verbal confirmation I received from Brown subsequently', 1),
#  (' I headed to a Wells Fargo branch in XXXX XXXX', None, 1),
#  (" I honestly believe Chase 's practice of clearing pending charges at XXXX at night and then having any direct deposit come in shortly after XXXX is an Unfair", None, 1),
#  (' I in no way was expecting to be relieved of my responsibility for the balance', None, 1),
#  (' I just called - and an employee said I needed to talk to someone in customer service. They gave me the telephone number', None, 1),
#  (' I kept getting AUTO GENERATED letters that information was verified with the furnisher thus it should stay on the record. When contacted furnisher-  ... (26 characters truncated) ... alifornia-they confirmed in writing that they DO NOT REPORT OR VALIDATE any information to none of the bureaus ... VERIFICATION BY EXPERIAN WAS A LIE', None, 1),
#  (' I know I qualify for a Loan Modification', None, 1),
#  (' I learned about "" insufficient funds \'\' fees and how those are different than "" overdraft fees \'\'. If you pay some of your monthly bills automatically', None, 1),
#  (' I learned that the mortgage company has had an expired license since 2009. Then I asked the licensed real estate agent who did the paperwork in the  ... (233 characters truncated) ... ts on people. CREDCO has not responded to my email about it. It seems to me that CREDCO should know whether or not its customers are even in business', None, 1),
#  (' I left XXXX yet another voice mail sharing my expectation that the funds were back in my hands by the end of the week. I received neither a response nor the check. When I called today', None, 1),
#  (' I made a purchase in XXXX', None, 1),
#  (' I met with assistant store manager', None, 1),
#  (' I never received any bill for this service until now', None, 1),
#  (' I never received the XX/XX/XXXX statement so no payment was made. When the next statement came it had penalty and interest so i called to find out why and discovered the missing statement', None, 1),
#  (' I overpaid {$200.00} in response to Synchrony \'s demand for {$110.00} to allegedly bring my account "" current', ' Account XXXX', 1),
#  (' I paid the XXXX dollars to get this lifted on XXXX/XXXX/2016 and then they XXXX XXXX can back and said they could run file because I had a federal fraud alert on my phone number. My phone number was not listed in my file', None, 1),
#  (' I pity the less sophisticated', '681XX', 1),
#  (' I provided Experian a copy of a government identification', None, 1),
#  (' I provided the requested information to TSI', None, 1),
#  (' I pulled XXXX and XXXX as well. Sure enough', 'Collections Acquisition Company, Inc.', 1),
#  (' I pulled up my account online and saw that there was a fraudulent hold placed on my account as I was overseas. Called citibank and spoke to different consultants and managers but no ones seems to know how to help me. They ask me for my personal informations like account password', None, 1),
#  (' I put an offer on a house. It was a XXXX foreclosure home owned by the XXXX XXXX. After many transfers of paperwork and paying for home inspections', " there are too many repairs for the bank that is approving your loan to deal with ''. So I lost the house and money I spent on everything to get it approved At that point the vacation rental was already overdue for me to move out", 1),
# ...
#  (' XXXX. The XXXX website says that based on this date', None, 1),
#  (' XXXX. This is to advise you that despite the fact that YOU have received a response from Wells Fargo', ' do you do anything to justify your existance? Do you do any independent investigation of complaints? So in addition to my complaint against Wells Fargo', 1),
#  (" XXXX. XXXX for collections and they could provide no further info and that I 'd have to contact them ( XXXX ). I then made contact with XXXX the same day", ' Contact Us and Profile', 1),
#  (' XXXX/XXXX/16', None, 2),
#  (' XXXX/XXXX/2016', None, 2),
#  (' XXXX/XXXX/XXXX', None, 7),
#  (' XXXX/XXXX/XXXX', 'Company believes it acted appropriately as authorized by contract or law', 1),
#  (' XXXX/XXXX/XXXX and on Saturday', None, 1),
#  (' Your lawyer can request invoices', None, 1),
#  (' a XXXX mortgage', None, 1),
#  (' a banking institution with operations all over the world', None, 1),
#  (' a checked was bounced on me which caused my bank to bounce a check to Citicorp for payment on my credit card. I let them know in advance', None, 1),
#  (" a corrected bill will be sent. '' 4. In a new bill", None, 1),
#  (' a cosigner', None, 1),
#  (' a debt collector shall', ' or any portion thereof', 1),
#  (' a division of Hyundai Capital America ( "" HCA \'\' ) engaged in illegal', None, 1),
#  (' a look at the actual XXXX data provided by the XXXX XXXX XXXX XXXX clearly shows that the XXXX has been *decreasing* since the middle of XXXX', None, 1),
#  (' a money line of credit', None, 1),
#  (' a plummeting credit profile', None, 1),
#  (' a provider of legal services to the mortgage bankingIndustry', None, 1),
#  (' a representative told me that I was eligible for further 2 month forbearance on each loan. I called today to arrange these forbearances', None, 1),
#  (' a service does not have the rights of a holder in due course and therefore', None, 1),
#  (' about a year ago', None, 1),
#  (' access to a computer', None, 1),
#  (' according to internet search ) about unknown person. Nobody at our number ( XXXX ) has any debt and we are on the Do Not Call List. The robo-call leaves a message to call XXXX about XXXX (? ) XXXX (? ) a name we have no knowledge of. The company calls late at night', None, 1),
#  (' account type', None, 1),
#  (' accounts to claim full responsibility on', None, 1),
#  (' actual damages sustained by the consumer as a result of the failure or {$1000.00}', '', 1),
#  (' address', None, 1),
#  (' addresses', None, 1),
#  (' advice of counsel', ' \'\' Wells Fargo stated. "" However', 1),
#  (' after I refused to give my SSN but did give the rep the account number which was on the card', None, 1),
#  (' after along hold the associate told us the deposit transfer would take 2 days not 24hrs', None, 1),
#  (' after making big payments for a few years', None, 1),
#  (" after over two months of discussions -- Citi 's mortgage broker announced that our income was insufficient to qualify for both mortgages at once. ( Not insufficient for either loan", None, 1),
#  (' after reconfirming eligibility and terms via REST Report/Loan Disposition Analysis/NPV', None, 1),
#  (' after repeatedly calling Chase to confirm the payment amount. Thanks to the brilliant idea of a verbal mortgage! Our records also confirm that we first tried to make the second payment on-line but when it was not accepted', None, 1),
#  (' after speaking with XXXX XXXX XXXX ( did not have an offer for the property', None, 1),
#  (' after this Complaint to your agency', None, 1),
#  (' after this payment my account balance became XXXX . At XXXX/XXXX/2016 I called to costumer service by number XXXX', None, 1),
#  (' again', None, 2),
#  (' again this year they always have for the 3 years I have been with them. Ever since I have been with Quicken loans insurance agent has called me conc ... (262 characters truncated) ... s that it has been paid but it has not. One of the employees at QL did pass on to me that they use a 3 rd party vendor to pay all taxes and insurance', None, 1),
#  (' agony and negative reflection this has caused is unacceptable', None, 1),
#  (' all he can do is give me his business card with a note saying he had this discussion with me ; he gave me his card and dated and sign that he had the discussion with me. He then recommended that I go to my Bank', None, 1),
#  (' all individuals named below are CapitalOne employees ) : XXXX XXXX 2016 : I opened a savings account to capitalize on a "" new customer \'\' bonus ( {$500.00} ) advertised as being available 90 days after opening a savings account. I am informed CapitalOne "" prefers \'\' ( i.e.', None, 1),
#  (' all information', None, 1),
#  (' all via phone. Each time', ' but no calculations as to how that amount was determined. So far', 1),
#  (' almost all making serious criticism of HSBC', None, 1),
#  (' along with XXXX that put the pressure on us and refused to speak with me', None, 1),
#  (' along with XXXX {$120.00} late fees. That is wrong', None, 1),
#  (' along with proof of all owners from each subsequent transaction made when the note was packaged and sold and resold to investors who made investment decisions based on the packaged mortgage backed securities being represented to them that there was', None, 1),
#  (' although I was able to get out of my counseling job paying {$13.00} an hour after 12 years of service with that agency', ' I found a roommate to share expenses a month ago', 1),
#  (' although nowhere on the bill does it state that the closing date is the actual date on which the bill is printed. At minimum', None, 1),
#  (' among these account XXXX them was with bank of America. I had immediately contacted the credit bureaus and had notified them about my identity was s ... (317 characters truncated) ... f America that been giving me the run around for the past two and half years. I had send them the following letter certified mail more than ten times', None, 1),
#  (' amount', None, 2),
#  (' an identifier or their last name. However', None, 1),
#  (" an important buyers ' feature in XXXX XXXX XXXX XXXX XXXX ii", None, 1),
#  (' an incomplete account number and many pages of generic documents that did not apply to the case at all. Prior to court', None, 1),
#  (' and', None, 1),
#  (' and Chase the resolved the issue then', None, 1),
#  (' and I am forwarding this information to my Senator XXXX XXXX', None, 1),
#  (' and I believe that the note and security instrument were sold already', None, 1),
#  (' and I demanded my promisary note and proof of payments made since XX/XX/XXXX ( see attached ). AES continued to send me a bunch of nonsense regarding a "" deferment \'\' and a "" forbearance \'\' on my loan ... none of which I initiated. XX/XX/XXXX', None, 1),
#  (" and I faxed her copes of my information. XXXX followed up with XXXX XXXX and the bank 's legal department", ' and still do', 1),
#  (' and I found out that Syndicated Office Systems ( whom also goes by Central Financial Control ) put my account to collection. I called the phone # listed within my credit report', None, 1),
#  (' and I have had a difficult time coming to grips with the result of part of the outcome since. I am an honest hard working person', None, 1),
#  (" and I have recepts of checks that are not listed on payment history that I did n't receive credit for and Ocwen has the proof", None, 1),
#  (" and I was getting help from the bank 's VP. I was telling her about my situation and she suggested that I write you. She told me that you are a nice and understanding man. XXXX XXXX", None, 1),
#  (' and Insurance documents. XXXX providing information that this car is garaged at her home address "" a senior housing complex \'\' XXXX continues to report that I am a cosigner on this account the most compelling evidence', None, 1),
#  (' and SunTrust agreed', ' and landlords may not discriminate on the basis of race and national origin ( the Act also prohibits discrimination based on sex', 1),
#  (' and TransUnion continues to list the disputed item on my credit report I will find it necessary to sue you for actual damages and declaratory relief under the FCRA. According to this regulation', None, 1),
#  (' and TransUnion have come back to me and stated they were able to verify these inaccurate accounts. How is this possible? Under the laws of the FDCPA', None, 1),
#  (' and XXXX as a partial payment toward this month. See other email I sent to your company today for further explanation', None, 1),
#  (' and accecpted by', '', 1),
#  (" and after substantiating borrower 's default and servicer 's right to foreclose. XXXX XXXX b ). They violated the National Mortgage Settlement guidelines XXXX", None, 1),
#  (' and all accounts thereof are accepted for value', None, 1),
#  (' and also found out that XXXX XXXX is not an attorney as he told me he was. This evening', None, 1),
#  (' and also told them to contact the person and get their correct information', None, 1),
#  (' and always have been', None, 1),
#  (' and am not getting anywhere with it. The seller has also quit responding to all of my emails. I am about to close my PayPal account', 'Consent provided', 1),
#  (' and any remaining balance would be forgiven. I did as you asked. It now appears that you have failed', None, 1),
#  (' and being that he is the professional', None, 1),
#  (' and can not according to XXXX - as this data is not expected to be sent by a debt collector on this industry standard file. I have never been late with XXXX nor XXXX 8. XXXX account on EQ is reporting a creditor classification of "" RETAIL \'\' and can not', None, 1),
#  (' and confusion with my transactions. All in which were proven beyond my control', None, 1),
#  (' and during the deferral period before that', None, 1),
#  (' and enter an amount to pay', None, 1),
#  (' and extended family members', None, 1),
#  (" and found many customers have had issues with XXXX XXXX ' not honoring sign-up bonuses", None, 1),
#  (" and frustrating my lawful efforts to close my Father 's accounts. I am hoping CFPB can compel Bank of America to take my concerns seriously", None, 1),
#  (' and had no intention of honoring its agreement. I am aware that Midland records all of its phone calls', 'Consent provided', 1),
#  (' and have added it to my Trans Union and XXXX credit reports as a brand new Unpaid Charge Off Debt', None, 1),
#  (' and have been found that XXXX was one of their biggest profit makers', None, 1),
#  (' and have been told that', None, 1),
#  (' and he assured me they would handle it at XXXX. When I called THAT number', None, 1),
#  (' and how to proceed if you do n\'t think you owe the money. The last option was not give to me. Both companies attempted to hide information from the ... (304 characters truncated) ... ose the account so no one else can attempt to collect the debt in which both companies violated debt collection practices laws and arbitration laws."', 'Web', 1),
#  (' and if she will furnish our office what the dispute is', None, 1),
#  (' and if so', None, 1),
#  (' and if your Agency fails to find probable cause', None, 1),
#  (' and in the order they occurred', None, 1),
#  (' and its Pay Status', 'Consent provided', 1),
#  (' and last', None, 1),
#  (' and let me know. I had no problem getting the same from XXXX and XXXX. Thanks', 'Consent provided', 1),
#  (' and letters', None, 1),
#  (' and many times completely inaccurate information. Aside from the moral obligation', 'Consent provided', 1),
#  (' and marketing loan products to avoid and thereby discourage prospective borrowers in predominantly XXXX and XXXX neighborhoods in at least XXXX Metropolitan areas. Wells Fargo has a history of case management procedures which are wrong and illegal. During the relevant period', None, 1),
#  (' and moneys to purchase property. Realtor representing seller knew that property was not eligible for sale on XXXX XXXX 2016 when listed for sale and on XXXX XXXX', '782XX', 1),
#  (' and my loan payment is still pretty high', None, 1),
#  (' and no results provided. I called the hospital and they had no records of any lab work. The debt was only {$170.00} and now my credit score has take ... (107 characters truncated) ...  into it. I was unaware they reported it because other than the second letter they sent me which only contained a print out of medical coding screens', None, 1),
#  (' and not Current in its PAY STATUS 3. This account is missing Pay History 4. This account is missing Balance History 5. Please validate this account', 'Consent provided', 1),
#  (' and not serve the public."', 'Web', 1),
#  (' and noticed that Chase made incorrect calculations. On the application', None, 1),
#  (' and now they just filed a judgement of debt for {$220.00}', None, 1),
#  (' and on page XXXX', None, 1),
#  (' and once again we did not receive a detailed reason for the denial', None, 1),
#  (' and only received XXXX TPP under HAMP. He further meets all basic criteria for HAMP eligibility as outlined in section XXXX', None, 1),
#  (' and other information incorrect in my IDENTIFICATION VERIFICATION."', 'Web', 1),
#  (' and please correct the Activity designator to "" CLOSED \'\' - Willfully violate obligations under the FCRA', '', 1),
#  (" and prevent me from paying it off early. Why would an account like 'unapplied amount ' even exist? Except to criminally hold my money", None, 1),
#  (' and protect consumers from this predatory abuse', None, 1),
#  (' and requested an appeal or other process to reduce what I am being told is a mandatory minimum payment to "" Rehabilitate \'\' the Loan. The student loan manager emailed me back stating that the collection agency is correct', None, 1),
#  (' and seems to be a matter of unfair', None, 1),
#  (' and she said it takes 10 business day for a reply to be generated - it would have been nice if the person that answered my first call would have said that', None, 1),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 13 y ... (16 characters truncated) ...  no Balance History in this account - and there should be as this account was opened for over 13 years 4. Because this account has no Payment History', None, 2),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 3 ye ... (14 characters truncated) ... s no Balance History in this account - and there should be as this account was opened for over 3 years 4. Because this account has no Payment History', None, 3),
#  (' and since then I have been unable to find any. I am living with my mother for the first time in a decade', None, 1),
#  (' and spoke and received letters from BOA executive office and NO ONE offered me the core account. NO ONE! This would have been a very easy fix as I already had direct deposit anyway!!! I am so mad that all I received was explanations and copies of my CM agreement', ' commended for great customer service and some knowledge about the accounts. Maybe she should be in the executive office! Please', 1),
#  (' and spoke to XXXX ( Customer Service Agent ) who completely refused to help. I then asked to speak to a supervisor', None, 1),
#  (' and still', None, 1),
#  (' and still be able to provide the beneficiary with a XXXX repayment', None, 1),
#  (' and temperatures in the XXXX', ' and found someone with a truck to tow me into town. One week later I was able to charter a flatbed truck passing down the road on its way to XXXX', 1),
#  (' and that I had no reason to anticipate such blatant disregard for my time and situation. Travel plans have had to be postponed due to these unjustified delays', ' but merely designed to take advantage of their customers during a time when cooperation from their lender is most needed. It is a shameful and demeaning way to operate a business."', 1),
#  (' and that I need to pay in order for them to do anything', 'Consent provided', 1),
#  (' and that his communication was an attempt to collect a debt', None, 1),
#  (' and that is NOT LAWFUL! I have no proof', None, 1),
#  ...]

# %% [markdown]
# ### (b) Queries con un índice de un solo campo (10 puntos)
#
# A continuación cree un indice de un solo campo que mejore el tiempo de respuesta de su query.
#
# Recuerde que la sintaxis para creación de queries es:
#
# > DROP INDEX IF EXISTS index_name;
# > CREATE INDEX index_name ON table(attributes);

# %%
# %sql DROP INDEX IF EXISTS test; CREATE INDEX test ON complaints(Product, State);
# Out:
#  * sqlite:///complaint.db
# Done.
# Done.
# []

# %% [markdown]
# Ejecute nuevamente su query inicial para verificar que el tiempo de respuesta mejoró:

# %%
# %time %sql SELECT Product,State,count(*) FROM complaints GROUP BY Product, State
# Out:
#  * sqlite:///complaint.db
# Done.
# Wall time: 31.2 ms
# [(None, None, 13451),
#  ('', None, 1),
#  ('', '01/01/2016', 1),
#  ('', '01/02/2016', 7),
#  ('', '01/03/2016', 9),
#  ('', '01/04/2016', 17),
#  ('', '01/05/2016', 16),
#  ('', '01/06/2016', 19),
#  ('', '01/07/2016', 26),
#  ('', '01/08/2016', 17),
#  ('', '01/09/2016', 6),
#  ('', '01/10/2016', 8),
#  ('', '01/11/2016', 23),
#  ('', '01/12/2016', 23),
#  ('', '01/13/2016', 17),
#  ('', '01/14/2016', 19),
#  ('', '01/15/2016', 25),
#  ('', '01/16/2016', 6),
#  ('', '01/17/2016', 8),
#  ('', '01/18/2016', 12),
#  ('', '01/19/2016', 12),
#  ('', '01/20/2016', 27),
#  ('', '01/21/2016', 22),
#  ('', '01/22/2016', 15),
#  ('', '01/23/2016', 6),
#  ('', '01/24/2016', 4),
#  ('', '01/25/2016', 10),
#  ('', '01/26/2016', 36),
#  ('', '01/27/2016', 29),
#  ('', '01/28/2016', 26),
#  ('', '01/29/2016', 19),
#  ('', '01/30/2016', 6),
#  ('', '01/31/2016', 4),
#  ('', '02/01/2016', 26),
#  ('', '02/02/2016', 20),
#  ('', '02/03/2016', 26),
#  ('', '02/04/2016', 22),
#  ('', '02/05/2016', 20),
#  ('', '02/06/2016', 12),
#  ('', '02/07/2016', 8),
#  ('', '02/08/2016', 16),
#  ('', '02/09/2016', 19),
#  ('', '02/10/2016', 25),
#  ('', '02/11/2016', 16),
#  ('', '02/12/2016', 24),
#  ('', '02/13/2016', 7),
#  ('', '02/14/2016', 9),
#  ('', '02/15/2016', 5),
#  ('', '02/16/2016', 13),
#  ('', '02/17/2016', 25),
#  ('', '02/18/2016', 33),
#  ('', '02/19/2016', 29),
#  ('', '02/20/2016', 10),
#  ('', '02/21/2016', 8),
#  ('', '02/22/2016', 26),
#  ('', '02/23/2016', 17),
#  ('', '02/24/2016', 31),
#  ('', '02/25/2016', 17),
#  ('', '02/26/2016', 24),
#  ('', '02/27/2016', 13),
#  ('', '02/28/2016', 6),
#  ('', '02/29/2016', 12),
#  ('', '03/01/2016', 29),
#  ('', '03/02/2016', 22),
#  ('', '03/03/2016', 20),
#  ('', '03/04/2016', 19),
#  ('', '03/05/2016', 11),
#  ('', '03/06/2016', 12),
#  ('', '03/07/2016', 17),
#  ('', '03/08/2016', 35),
#  ('', '03/09/2016', 22),
#  ('', '03/10/2016', 21),
#  ('', '03/11/2016', 22),
#  ('', '03/12/2016', 11),
#  ('', '03/13/2016', 7),
#  ('', '03/14/2016', 14),
#  ('', '03/15/2016', 27),
#  ('', '03/16/2016', 23),
#  ('', '03/17/2016', 21),
#  ('', '03/18/2016', 16),
#  ('', '03/19/2016', 7),
#  ('', '03/20/2016', 5),
#  ('', '03/21/2016', 19),
#  ('', '03/22/2016', 31),
#  ('', '03/23/2016', 20),
#  ('', '03/24/2015', 1),
#  ('', '03/24/2016', 21),
#  ('', '03/25/2016', 19),
#  ('', '03/26/2015', 1),
#  ('', '03/26/2016', 13),
#  ('', '03/27/2016', 3),
#  ('', '03/28/2016', 22),
#  ('', '03/29/2016', 26),
#  ('', '03/30/2016', 20),
#  ('', '03/31/2016', 10),
#  ('', '04/01/2015', 1),
#  ('', '04/01/2016', 25),
#  ('', '04/02/2016', 11),
#  ('', '04/03/2016', 10),
#  ('', '04/04/2016', 25),
#  ('', '04/05/2016', 25),
#  ('', '04/06/2016', 25),
#  ('', '04/07/2015', 1),
#  ('', '04/07/2016', 19),
#  ('', '04/08/2016', 24),
#  ('', '04/09/2016', 10),
#  ('', '04/10/2016', 3),
#  ('', '04/11/2016', 27),
#  ('', '04/12/2016', 30),
#  ('', '04/13/2015', 1),
#  ('', '04/13/2016', 22),
#  ('', '04/14/2016', 17),
#  ('', '04/15/2016', 20),
#  ('', '04/16/2015', 2),
#  ('', '04/16/2016', 6),
#  ('', '04/17/2016', 7),
#  ('', '04/18/2016', 18),
#  ('', '04/19/2016', 22),
#  ('', '04/20/2015', 1),
#  ('', '04/20/2016', 20),
#  ('', '04/21/2016', 21),
#  ('', '04/22/2016', 18),
#  ('', '04/23/2016', 9),
#  ('', '04/24/2016', 5),
#  ('', '04/25/2016', 13),
#  ('', '04/26/2016', 8),
#  ('', '04/27/2016', 23),
#  ('', '04/28/2016', 19),
#  ('', '04/29/2015', 1),
#  ('', '04/29/2016', 24),
#  ('', '04/30/2015', 1),
#  ('', '04/30/2016', 5),
#  ('', '05/01/2016', 5),
#  ('', '05/02/2016', 23),
#  ('', '05/03/2016', 26),
#  ('', '05/04/2016', 18),
#  ('', '05/05/2016', 21),
#  ('', '05/06/2016', 15),
#  ('', '05/07/2016', 2),
#  ('', '05/08/2016', 9),
#  ('', '05/09/2016', 17),
#  ('', '05/10/2016', 23),
#  ('', '05/11/2016', 20),
#  ('', '05/12/2015', 1),
#  ('', '05/12/2016', 14),
#  ('', '05/13/2016', 10),
#  ('', '05/14/2016', 12),
#  ('', '05/15/2015', 1),
#  ('', '05/15/2016', 1),
#  ('', '05/16/2016', 10),
#  ('', '05/17/2016', 7),
#  ('', '05/18/2016', 19),
#  ('', '05/19/2016', 10),
#  ('', '05/20/2015', 1),
#  ('', '05/20/2016', 8),
#  ('', '05/21/2016', 6),
#  ('', '05/22/2015', 1),
#  ('', '05/22/2016', 4),
#  ('', '05/23/2016', 12),
#  ('', '05/24/2016', 6),
#  ('', '05/25/2016', 8),
#  ('', '05/28/2015', 1),
#  ('', '06/03/2016', 1),
#  ('', '06/07/2016', 1),
#  ('', '06/10/2016', 1),
#  ('', '06/14/2016', 1),
#  ('', '06/15/2016', 2),
#  ('', '06/21/2016', 1),
#  ('', '06/24/2015', 1),
#  ('', '06/25/2015', 1),
#  ('', '06/30/2015', 1),
#  ('', '07/13/2015', 1),
#  ('', '07/14/2015', 1),
#  ('', '07/17/2015', 1),
#  ('', '08/08/2015', 1),
#  ('', '08/12/2015', 1),
#  ('', '09/02/2015', 1),
#  ('', '09/24/2015', 1),
#  ('', '09/30/2015', 1),
#  ('', '10/20/2015', 1),
#  ('', '10/27/2015', 1),
#  ('', '11/12/2015', 1),
#  ('', '11/18/2015', 1),
#  ('', '11/20/2015', 1),
#  ('', '12/02/2015', 8),
#  ('', '12/07/2015', 2),
#  ('', '12/08/2015', 15),
#  ('', '12/09/2015', 12),
#  ('', '12/11/2015', 1),
#  ('', '12/12/2015', 10),
#  ('', '12/13/2015', 7),
#  ('', '12/14/2015', 12),
#  ('', '12/15/2015', 14),
#  ('', '12/16/2015', 18),
#  ('', '12/17/2015', 9),
#  ('', '12/18/2015', 20),
#  ('', '12/19/2015', 3),
#  ('', '12/20/2015', 5),
#  ('', '12/21/2015', 16),
#  ('', '12/22/2015', 10),
#  ('', '12/23/2015', 14),
#  ('', '12/24/2015', 11),
#  ('', '12/26/2015', 5),
#  ('', '12/27/2015', 3),
#  ('', '12/28/2015', 19),
#  ('', '12/29/2015', 9),
#  ('', '12/30/2015', 12),
#  ('', '12/31/2015', 15),
#  ('', 'Consent not provided', 2),
#  ('  a TSYS Company"', 'Closed with explanation', 3),
#  ('  a TSYS Company"', 'Closed with monetary relief', 1),
#  (' "" ACCORDING TO THEIR SCHEDULE \'\'', None, 1),
#  (' "" Amount Due \'\' of : {$1100.00} XXXX XXXX', None, 1),
#  (' "" I understand you are upset because you were n\'t offered some sort of physician discount. \'\' Nope', None, 1),
#  (' "" Once the property is sold and the debt is paid', ' for servicing. Immediately after the financial meltdown of XXXX', 1),
#  (' "" Once your 90 day waiting period is complete', None, 1),
#  (' "" Our records indicate you have not made your last four or more regularly scheduled payments. Subject to applicable law', " we are offering you an opportunity to enter into a Trial Period for a loan modification ... '' I have in fact made payments for the entire time peri ... (156 characters truncated) ... merous Bank of America personnel in various departments ( See communication notes ) who transferred me back and forth between them with no resolution", 1),
#  (' "" They the agreed with PNC and are not changing the amount I owe. \'\' I also asked her to put how they came up with this agreement in writing and she said', 'Consent provided', 1),
#  (' "" Transactions should be processed in a neutral order that avoids manipulating or structuring processing order to maximize customer overdraft and related fees. Examples of a neutral order include order received', None, 1),
#  (' "" Which of these best describes your issue?', None, 1),
#  (' "" Who is XXXX? \'\' I asked him this because when the payments are taken out of my account my account shows the payments are going to a company named XXXX. XXXX XXXX told me his client was XXXX XXXX', None, 1),
#  (' "" XXXX XXXX', None, 1),
#  (' "" Yes. \'\' The man then said', ' "" No', 1),
#  (' "" Your creditor or debt collector believes that the legal time limit ( statute of limitations ) for suing you to collect this debt may have expired. It is a violation of the Fair Debt Collection Practices Act', None, 1),
#  (' "" how can a person who ca n\'t pay X', None, 1),
#  (' # XXXX', '705XX', 1),
#  (' # XXXX XXXX', None, 1),
#  (" '' 91 Stat. 874 ( XXXX )", 'OH', 1),
#  (" '' I do n't anticipate this complaint doing much good", None, 1),
#  (' \'\' and "" workout plans. \'\' We had made all of our payments on time. In another set of documents', ' we repeatedly called Bank of America for clarification', 1),
#  (" '' and my loan was magically put into forbearance. If the policy did in fact change the day after CFPB notified Wells Fargo of my complaint", None, 1),
#  (" '' and that they notified the other credit reporting agencies of the same information. I immediately called them", None, 1),
#  (' \'\' based ona "" range of potential losses for each matter that is both probable and estimable. \'\' Wells Fargo stated that the "" high end of the ... (12 characters truncated) ... asonably possible potential litigation losses in excess of the company \'s liability for probable and estimable losses was approximately {$1.00} XXXX', None, 1),
#  (" '' but when I asked why I never received a voice mail", None, 1),
#  (' \'\' or persons who furnish information to consumer reporting agencies ( "" CRA \'\' ) such as credit bureaus. In particular', None, 1),
#  (" '' that was purportedly signed by me", None, 1),
#  (" '' the CFPB said", None, 1),
#  (" '' which still leaves their prior negative information on my credit reports and negatively effects my credit scores. I was very specific in my request", None, 1),
#  (" 'executives ' are working on a lump sum settlement for all claims. Once a settlement is reached", ' a settlement', 1),
#  (' ( 6 months before it was due )', None, 1),
#  (' ( Credit Union ) response is that the information you have disputed is both true and correct according to all available documentation. As such', None, 1),
#  (' ( I was told that there was an issue with my expenses being too low and I was told that the underwriter took the initiative to calculate them at a higher amount even if they were not my actual expenses. ) XXXX XXXX', None, 1),
#  (' ( XXXX ) "" Seizures for Property \'\'', None, 1),
#  (' ( business plan', None, 1),
#  (' ( the settlement amount that I also have in canceled checks )', None, 1),
#  (' 1 week after yielding my physical address to AMEX', None, 1),
#  (' 12 CFR 226.15 ( b ) of Regulation Z states "" In any transaction or occurrence subject to rescission', None, 1),
#  (' 15 USC 1692', None, 1),
#  (' 2 months after closing my account and receiving a "" credit balance refund check. \'\' for {$2400.00} from them. May I please add that my account with them had a {$3000.00} CREDIT LIMIT! How can I possibly owe them {$600.00}?? Now my credit is being affected', None, 1),
#  (' 2013', None, 1),
#  (' 2015', None, 5),
#  (' 2015', 'Altisource Portfolio Solutions, S.à r.l.', 1),
#  (' 2015 ( relative to Nationstar/XXXX Notice of Debt Validation dated XX/XX/2015- with 30 day to validate debt ; then Nationstar violates FDCPA by recording the Notice of Default two days later', None, 1),
#  (' 2015 XXXX sent via email', None, 1),
#  (' 2015 by XXXX XXXX in XXXX', None, 1),
#  (' 2015 letter that FHA requires borrowers to provide a statement. I am providing documentation from FHA guidelines', None, 1),
#  (' 2015 not trying to validate the debt but to make a settlement offer', None, 1),
#  (" 2015 now through XXXX/XXXX/15. Rewards earned are in addition to your standard rewards and are added to your Miles account within 2 billing periods. ... (86 characters truncated) ... ged in deceptive marketing practices. They marketed a promotion promising amazing rewards with no cashback and after getting new customers to sign up", None, 1),
#  (' 2015 stating that I had to pay {$830.00} to cure the loan. Five days prior to the date of the letter I had already sent in a payment of {$820.00} via XXXX and then on XXXX XXXX', None, 1),
#  (' 2015. I provided a full written explanation and copies of the supporting evidence. As part of the investigation process', None, 1),
#  (' 2015. I think they are trying to collect for XXXX', None, 1),
#  (' 2015. The card has an annual fee of {$95.00} and it has an offer related to reimbursement of upto {$650.00} incurred towards purchase of new cellphone from AT & T provided new user spends {$2000.00} within 3 months. However', None, 1),
#  (' 2016', None, 7),
#  (' 2016 I contacted Commonwealth Financial Services to potentially pay off a debt. After talking with a lady who told me her name was XXXX XXXX we came ... (125 characters truncated) ... erification that the amount I was paying off was in writing. She emailed me XXXX verifications. I in return paid {$100.00} to settle a {$150.00} debt', None, 1),
#  (' 2016 I informed TD Bank that I was withdrawing my loan application due to their refusal to honor the terms of my original rate lock agreement. Due t ... (86 characters truncated) ... w lender I applied with sought an agreement to extend the deadline for the purchase and sales agreement between myself and the sellers. Unfortunately', None, 1),
#  (' 2016 I initiated an online dispute regarding the inaccurate reporting of inquiries and previous addresses on my Equifax file. Prior to that', None, 1),
#  (' 2016 I received a phone call stating that I received an {$8000.00} grant and in order to get the grant I had to give the account and routing number for my bank. The further instructions were to go to an ATM and pull out {$300.00}', None, 1),
#  (' 2016 I submitted a complaint to CFPB # XXXX "" Case number XXXX with response \'\'', None, 1),
#  (' 2016 I was notified on my online account that I was overdrawn. Knowing that I should have had funds I went online and checked and saw that Chase had reversed the credits from the dispute. This time instead of calling just the dispute center I called my local Chase Branch ( XXXX XXXX XXXX XXXX', None, 1),
#  (' 2016 TD Bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure indicated the correct loan', None, 1),
#  (' 2016 TD bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure again had the wrong terms', None, 1),
#  (' 2016 XXXX RESIDENT SCREENING Date : XXXX XXXX', ' 2016 XXXX XXXX XXXX Date : XXXX XXXX', 1),
#  (' 2016 are Attachments # XXXX "" BBVA XXXX XXXX XXXX letter-password reset \'\' and # XXXX "" BBVA deposit XX/XX/XXXX withdrawal XX/XX/2016.XXXX-balan ... (130 characters truncated) ...  Besides the absence of communication from the bank that results in lack of consumers knowledge of his account it shows contempt towards the customer', None, 1),
#  (" 2016. '' Recent phone calls from representative XXXX XXXX of the Collections Department of Navient Solutions ", None, 1),
#  (' 2016. \'\' Under the "" Address \'\' section of my "" Experian \'\' credit report it lists a false address of "" XXXX. XXXX XXXX ; XXXX', None, 1),
#  (' 2016. I have not received any documents."', 'Web', 1),
#  (' 3', None, 1),
#  (' 6 days after the XXXX due date. This meant that Wells Fargo \'s own process for refunding a payment that should have applied to XXXX would indeed ha ... (200 characters truncated) ... heir debts? I raised this question to the Wells Fargo staff who informed me this was "" just the way it is. \'\' To which I responded with skepticism', None, 1),
#  (' ALL INFORMATION OUTDATED SINCE 2005 AND ALL AGENCIES VIOLATES FCRA PROVISION XXXX', None, 1),
#  (" AND LACK OF GOOD FAITH IN YOUR DEALINGS WITH US AND OTHERS. ALL YOU EVER SEND TO US OR OUR STATE AND GOVERNMENT OFFICIAL 'S ARE OUR PAYMENT HISTORY", None, 1),
#  (' AND NEVER GOTTEN PROOF', None, 1),
#  (' ATTORNEY REPORTED MCCALLA RAYMER LLC WILL FILE SOMETHING CALLED CONTESTED MATTER TO RETURN TO COURT TO DISMM WHAT THEY CALL MOTION FOR RELIEF FROM A ... (192 characters truncated) ...  RELATED TO XXXX XXXX XXXX PAST XXXX AND MCALLA RAYMERS ASSOCIATES. CURRENTLY RECIEVING PREMISSION AND NOTARY STATEMENTS TO RELEASE THESE DOCUMENTS."', 'Web', 1),
#  (' Ally reposed the car from my mom place of residence. After the car was reposed by Ally', None, 1),
#  (' Alpha Recovery now has the debt and will not provide me with information nor have I been able to speak with someone who is reasonable and honest."', 'Web', 1),
#  (' Amazon', None, 1),
#  (" Amount Due '' of : {$1100.00}", None, 1),
#  (' Attorney -- -- -- -- -- -- -- -- -- -- -- -- -- - XXXX Virginia XXXX Office XXXX Mobile XXXX Mobile XXXX Email : XXXX XXXX ( Assistant ) -- -- -- -- -- -- -- -- - XXXX Non-Attorney Staff Member XXXX Virginia XXXX Office XXXX Fax XXXX"', 'Web', 1),
#  (' Attorney at Law', '02/05/2016', 1),
#  (' Authorized Representative', None, 1),
#  (' BANA has never merged with BofA Merrill Lynch Asset Holdings ', ' XXXX. CWHL', 1),
#  (' BB & T started adding additional fees to my note. They added the following fees : 1 ) {$1000.00} fee for XXXX appraisal fees -- why they would want  ... (64 characters truncated) ...  refinance is unexplainable. There is a provision in the contract that states if an appraisal is necessary I would be responsible for that fee. Again', None, 1),
#  (' BOA changed the property address to my XXXX home address and not my XXXX home address. The XXXX home is the collateral for a less than {$95000.00} modified equity line. In addition', None, 1),
#  (' BSI Financial Services', None, 1),
#  (' Bank of America. After a very frustrating process of them losing documents and re-asking for documents that I had already submitted', None, 1),
#  (' Barclaycard certified mail receipt and BarclaycardletterforACH ) because this account seems to have been confused and link to a bankruptcy that I fi ... (294 characters truncated) ... r pickup. I used the address provided by Barclay in the CFPB complaint response # XXXX at the bottom of their letter Card Services P.O. Box XXXX XXXX', None, 1),
#  (' Beal & Nixon', '02/25/2016', 1),
#  (' Bluebird XXXX XXXX XXXX XXXX XXXX XXXX', ' this bluebird account allows me to make deposits into my account easily but then they freeze my account every month while they verify everything."', 1),
#  (' BoA refuses to credit the {$38.00} because somewhere in a revised terms of service', None, 1),
#  (' BoA was never going to recoup the losses they assumed from Countrywide. As such', None, 1),
#  (' Branch Manager XXXX # XXXX HomeBridge Financial Services ', None, 1),
#  (' Burgess & Wolff', '12/21/2015', 1),
#  (" But did see on XXXX and all the inquires on Transunion credit. I know I have some outstanding debt. Probably close to XXXX with right XXXX price adj ... (449 characters truncated) ... t I would appreciate and cooperate in anyway for your help addressing these issues. Because I just do n't have the XXXX clarity to fight these issues", None, 1),
#  (' CA', None, 1),
#  (' CALIFORNIA XXXX TEL. NO ( XXXX ) XXXX', None, 1),
#  (' CMS guidelines also renders a loan ineligible to receive an alternative loan modification after receiving and defaulting under a HAMP Tier II TPP or a permanent HAMP Tier II loan modification under the same circumstances as outlined above. For this reason', None, 1),
#  (' Caliber Home Loans is and was', None, 1),
#  (' Case XXXX', None, 1),
#  (' Cash Advance Centers', '01/23/2016', 1),
#  (' Chase \'s counsel admitted that the denial was a "" streamline denial. \'\' She confirmed that the denial was not based on any information in the XXXX XXXX application because Chase had not actually reviewed it. The court directed that Chase review the XXXX XXXX application. On XXXX/XXXX/XXXX', None, 1),
#  (" Chase 's counsel emailed XXXX a letter denying XXXX for a Chase Modification", None, 1),
#  (' Chase XXXX', None, 1),
#  (' Chase did not correct the error', None, 1),
#  (' Chase was blaming the HOA first and', None, 1),
#  (" Citibank 's Illinois legal department refused the POA/XXXX submitted to the branch office. They instructed my cousin to call again or go to the XXXX XXXX in XXXX for notarization of there XXXX form", None, 1),
#  (' Citibank should be made to suffer the entire loss in the amount of {$1900.00}. Instead', None, 1),
#  (' Civil Code section 2923.5 requires lender to contact borrower in default and "" assess the borrower \'s financial situation and explore options for  ... (163 characters truncated) ...  CA. Homeowner Bill of Rights also provides that dual tracking protections can also protect homeowners who have been previously denied a modification', None, 1),
#  (' Complete and not in conflict with the account OPEN DATE and the CLOSURE DATE OR', None, 1),
#  (' Cruise and Smith LLC"', 'Untimely response', 1),
#  (' Customer Care 7 ) QUESTION FOR YOU : Am I not entitled to know how my bank uses ( lends or invests ) the money I deposit? Oil and gas is taking a huge hit right now and I want to know how my bank is exposed to losses. Is that not my right', None, 1),
#  (" DC also habitually charged late fees of {$39.00} even when I was n't late. I realize that they were doing this until after about a year of helping my mother-in-law when she passed away from XXXX. I called DC many times during my lunch break to have the late fees reimbursed. The refused. Finally", None, 1),
#  (" Debt collection agency. '' This is clearly confusing and misguiding consumers", None, 1),
#  (" Defendant 's principal place of businessis located at XXXX", None, 1),
#  (' Defendant filed a state court action againstPlaintiff on XXXX XXXX', None, 1),
#  (' Equifax ( r ) and XXXX ( r ) and any finance and other charges related to the fraudulent', None, 1),
#  (" Equifax is bounded in the terms set forth in the FCRA. Also let me remind you that under section 611 of the FCRA that you are required to investigate the completeness or accuracy of any item of information contained in a consumer 's file", None, 1),
#  (' Experian could not have conducted a reasonable reinvestigation to verify the accuracy of the disputed information. The FCRA clearly states that a cr ... (147 characters truncated) ... solely on hearsay information from the information source and shifted the burden back to me to contact the original creditor to verify these accounts', None, 1),
#  (' Experian has failed to complete their investigation within the 30-days', None, 1),
#  (' Experian has prevented Credit XXXX from getting my report and score. All info that I have provided to XXXX in XXXX has been exactly what I have given Experian when I obtained my free credit report today ( XXXX/XXXX/XXXX ). When I again tried CS today', None, 1),
#  (' Failed to show documentation that I have requested and failed to produce the note and Proof of Assignments to service my loan. XXXX also WILLINGLY and KNOWINGLY LIED ABOUT THE TRUSTEE AND OWNER OF THE NOTE by sending me the same LIE FILLED Note', None, 1),
#  (' Federal or CFPB guidelines. They think it is a joke."', 'Web', 1),
#  (' Florida has been contacted in each instance', None, 1),
#  (' From XXXX sent by wells Fargo in the year XXXX to us confirming the cancellation of this debt. Marked as XXXX ( This should have been done in the year XXXX and not in XXXX', None, 1),
#  (' GA XXXX \'\' Because the message is so vague ( "" a condition exists \'\' )', 'Consent provided', 1),
#  (' GA XXXX To whom it may concern : In accordance with Federal Civil Rights Law', None, 1),
#  (' GA XXXX"', 'Web', 1),
#  (' General Counsel for XXXX', ' legitimate cashier \'s checks bear the telephone number of the issuing institution ( which the counterfeit check did not ) and the check in question bore a suspicious "" security features box located on the reverse side. \'\' Therefore', 1),
#  (' Global Client Solutions', None, 1),
#  (' HSBC issued a response indicating the credit card account ending - XXXX is closed and that the credit will be deposited to my bank account. Please refer to Case number : XXXX. However', None, 1),
#  (' HUD', None, 1),
#  (" I 'm paraphrasing", None, 1),
#  (" I 'm sure you 'll want to handle this matter as soon as possible. For this purpose", None, 1),
#  (" I 've never had an XXXX account in my life but yet a debt of {$73.00} appears on my credit report", None, 1),
#  (" I 've resorted to filing this federal complaint due to the sinister organizational structure BofA has erected to try to get its customers to give up on collecting any checking account bonus due. I hope CFPB", None, 1),
#  (' I DEMAND ALL OF THEIR CLAIMS TO BE BACKED UP BY PRESENTING Convincing', None, 1),
#  (" I DEMAND that CHASE BANk 's credit reporting department", None, 1),
#  (' I HAVE TO GIVE UP THE RIGHT TO GO AFTER THE STOLEN MONEY AND LOOK FORWARD TO ONLY XXXX INSTEAD OF XXXX! BUT HOMELESS', None, 1),
#  (' I WAS DEFRAUDED BY BOTH THE VENDOR AND XXXX ... ... ..THE CREDIT REPORT DOES NOT CONTAIN A DOFD OF XX/XX/XXXX AS REQUIRED BY FCRA THE PAYMENT TABLE IS ERRONEOUS', ' WITH ME NOT PRESENT', 1),
#  (' I also bank here locally on the XXXX at XXXX bank. I keep my same old Chase bank account so I can send money to my grandmother who also banks there', ' the day my paycheck was projected to clear. That was the day Chase closed my account. As a result of the failed wire XXXX Checks I wrote bounced including the XXXX to court', 1),
#  (' I am', None, 1),
#  (" I am a victim of identity theft since XXXX 2015 and I have filed a police report for that submitting all evidences to the authorities. I have called ... (200 characters truncated) ...  have received a notice from my credit monitoring service that my credit score went down XXXX points in one shot! Checking my report to see the cause", None, 1),
#  (" I am away for the winter from the billing address and have not gotten Capital One 's last forwarded bill. However", None, 1),
#  (' I am disputing an account that I do not owe. The credit bureaus claimed the debt has been verified by IQ Data International. I call IQ Data Internat ... (67 characters truncated) ...  itemization. IQ data claims they do n\'t have it and could n\'t provide one anyways since they are not "" actively collecting the debt. \'\' However', None, 1),
#  (' I am furious', None, 1),
#  (' I am ineligible? That does not make any sense. It looks like a bait and switch to me."', 'Web', 1),
#  (' I am just shocked that Discover Card would treat a customer in this fashion. There is nothing "" negative \'\' that I have done wrong. Actually', None, 1),
#  (" I am just wondering why you do n't have an option for choosing what amount to pay in automatic payments", None, 1),
#  (' I am left with XXXX bank statement', ' after XXXX years later', 1),
#  (' I am more than happy to pay for the items', None, 1),
#  (' I am not refusing to pay', None, 1),
#  (' I am requesting disclosure of the "" original creditors documentation \'\'', 'Servicemember', 2),
#  (' I am seeking clarification as to how payments are to be handled', None, 1),
#  (' I am still waiting for them to submit the Verification of Mortgage to XXXX. I have been told they can only fax it to me', ' we are trying to make a college decision. I also will stop receiving child support the day he graduates. I do not think Citimortgage has the right to delay the process of the refinance. Their business practices are awful', 1),
#  (' I am trying to figure out what they told me they would not send it to collections and still did. and he responds stating the same thing : "" I will  ... (220 characters truncated) ...  lie about my issue to XXXX. I also complained to XXXX but they have done nothing but say they can only go off of email record and not over the phone', 'Consent provided', 1),
#  (' I am unable to log in and am unable to contact them', None, 1),
#  (' I am very bothered by how XXXX has conducted business', None, 1),
#  (' I and about 10-15 other students sued the XXXX XXXX XXXX XXXX for breach of contract after finding out the XXXX XXXX XXXX XXXX said on average', None, 1),
#  (' I applied for the new card on-line', None, 1),
#  (' I applied to refinance my home loan and my credit score was crucial to obtaining an affordable loan for the next 30 years of my life! After the loan ... (161 characters truncated) ...  score and the debt to income ratio in a big way. I called Citibank XXXX customer service to see what it meant as my online hub showed NO payment due', ' what does that mean? And then was why there was a $ XXXX payment due but my Citibank hub showed no payment due? After much talking she got me togeth ... (28 characters truncated) ... nd I explained they pulled my credit WITHOUT my permission and to listen to my conversations. She tried to get me to the manager but no one picked up', 1),
#  (' I ask numerous of time', None, 1),
#  (' I asked Bank to reimburse me', None, 1),
#  (' I asked XXXX who at the bank makes the decision and he told me the Underwriters at US Bank makes the decisions. I asked him if I could speak with them to find out what factors decided the definitive yes or no to a business loan', None, 1),
#  (' I asked her to spell her name and she said in a very sarcastic way "" XXXX', 'Company believes complaint represents an opportunity for improvement to better serve consumers', 1),
#  (' I asked how to file and was told send a copy to their office', None, 1),
#  (' I asked if she had pulled calls from around that time frame as I had requested. She stated no', 'Consent provided', 1),
#  (' I asked my wife', " I finally got XXXX XXXX on the telephone ; he first stated he could not speak with me because my name was not on the checking account. I reminded hi ... (62 characters truncated) ... ly said he would probably mail it. I told him it was close to XXXX and we needed the check to do what needed to be done. He did n't say anything else", 1),
#  (' I asked them to provide the refinance paperwork ; however', None, 1),
#  (' I attempted to make several arrangements to catch up but fell short. As a result of that', None, 1),
#  (" I become ineligible for a HARP. '' If there is documentation stating the aforementioned quote", None, 1),
#  (' I began receiving calls again from WFDS', None, 1),
#  (' I believe that essential information about simple ground rules of the modification process were kept from me. I also believe that serious delays caused by the bank which inflated the amount of the loan over the years is not being considered by the underwriters. And finally', None, 1),
#  (' I believe this account is invalid because any original creditor that I had a balance with years ago', None, 1),
#  (' I believe this to be an unlawful attempt to extort funds from me', None, 1),
#  (' I called Honda back and asked again for help so I can keep my vehicle', None, 1),
#  (' I called XXXX directly again on XXXX/XXXX/16. I was told voice messages were left notifying me of the late payments', None, 1),
#  (' I called and filed for claim for XXXX out XXXX transactions cleared in bank statement. On XXXX/XXXX/2016', None, 1),
#  (' I called and submitted a call back request. I had to call XXXX additional times time to get a status update. Each time I was given a different time frame for the transaction refund ( XXXX biz days', None, 1),
#  (' I called back at XXXX and told them I have already spoken to them this week and that I will not have a different answer than what I have already giv ... (265 characters truncated) ... redit Services Inc ( XXXX ) @ XXXX I get a call and voicemail from XXXX XXXX at Sunrise Credit Services Inc . I call back @ XXXX and speak with XXXX ', None, 1),
#  (' I called customer service. They were helpful at first ... but promised action which they never delivered. ( For example', None, 1),
#  (' I called the Amazon Credit Card / Synchrony bank and managed to get my account number. While on the phone', None, 1),
#  (' I called them', None, 1),
#  (' I called to inquire about the replacement refund check. I again spoke to XXXX who told me that early in the month', None, 1),
#  (' I called to set up payment arrangements and speedy cash told me my account has went over to a third party collection agency. They also provided me with XXXX. I never provided them with my debit card from XXXX XXXX information. However', None, 1),
#  (' I can call many times if i get a busy or no answer but if I talk to a debtor to make a demand I really should not all XXXX times in a day. If I did not have money at XXXX', None, 1),
#  (' I can not believe that this shift in standards is a misunderstanding or an error made in good faith. When I raised the concern initially', None, 1),
#  (' I can not pay them', None, 1),
#  (' I can only lodge a complaint by phone. To prevent further charges to my account and because of my inability to reach BOA', None, 1),
#  (' I can see that she is only interested in having me pay money', 'First Advantage LNS Inc.', 1),
#  (' I checked in to be sure the miles would be posted as promised', None, 1),
#  (' I checked my FICO score and it was XXXX. Within one week ( today )', None, 2),
#  (' I checked my balance online and saw that all the XXXX transactions were pending', ' and found that the TCF ATM does not take deposits. The nearest branch is XXXX miles from my home', 1),
#  (" I contacted Wells Fargo 's agents advising them of my struggles to keep up with my mortgage payments. Wells Fargo 's agents offered me an opportunit ... (55 characters truncated) ... eparate loan modification packages. After what seemed like the run around and paper chase with agents requesting and re-requesting the same documents", None, 1),
#  (' I contacted customer service again', ' which to date', 1),
#  (' I contacted my bank', ' including a letter from the garage in XXXX that verified the work done in XXXX was not what I requested', 1),
#  (" I contacted the State 's Attorney General 's Office in XXXX", None, 1),
#  (' I continued to pursue my case and finally', ' no one is held accountable for his promise. In fact', 1),
#  (' I could not log on answering the questions as myself. I tried again about XXXX hour later and XXXX of the XXXX questions were geared for my sister in law', ' which is what SHE owns', 1),
#  (' I decided to send money to people on my mailing address for them to send me the card that arrived on XXXX. When they are ready to send', None, 1),
#  (" I demand to see Assignments. A major crime has been committed and It is very Obvious that they 've tried to Manipulate me and the legal System as we ... (84 characters truncated) ... nipulate CFPB as well. These XXXX companies are CRIMINALS and Have Many Fraud Complaints and Lawsuits Filed against them. By checking CFPB site alone", None, 1),
#  (' I did', None, 1),
#  (' I did my due diligence to protect myself and wished that PNC did the same for its cardholder."', 'Web', 1),
#  (' I did my research and found numerous complaints about this company as well as a news piece by investigative reporter "" XXXX XXXX \'\' that aired XXXX 2012 : XXXX"', 'Web', 1),
#  (' I did not feel comfortable. At this point', None, 1),
#  (' I discovered in 2015 that I am the victim of major identity theft. If someone opened up a fraudulent account with CitiBank', None, 1),
#  (" I do n't remember. I complete XXXX loan applications a month ''. At that time", None, 1),
#  (' I do not know what this account is nor did I ever sign any documentation with this company. I have disputed it several times and as you can see the  ... (91 characters truncated) ... ' this issue was never resolved? I received no validation documentation of what this is nor where my signature is nor that this account belongs to me', None, 1),
#  (' I entered my credit card number and it came back to me with', None, 1),
#  (' I eventually conducted a three way phone call with XXXX regional supervisor and a TD Bank supervisor. During the call', None, 1),
#  (' I expect that all adverse information will be withdrawn from the credit records of XXXX XXXX XXXX immediately. In the event such adverse information is not withdrawn', None, 1),
#  (" I expected my PayPal balance to reflect the cancellation quickly. It did n't. I finally got a XXXX rep with enough skills to get me the XXXX phone number and information. The information was that I needed to get PayPal support on the phone and conference in XXXX. XXXX confirmed on the phone", ' not theirs at all."', 1),
#  (' I explained myself again and he said I had the following options and I quote ; "" Make the payment in full', None, 1),
#  (' I explained that I never knew I had a debt and certainly would have worked this out with the hospital', ' I do the same thing', 1),
#  (' I faxed this written statement to the number provided. On XXXX/XXXX/16', None, 1),
#  (' I feel as though XXXX XXXX XXXX', ' have some of my debt removed and my credit cleaned up. I was young', 1),
#  (' I feel it is BAD PRACTICE for Capital One to not put SOMETHING', None, 1),
#  (' I feel like somewhere I received some bad student loan advice and possibly made some errors along the way. XXXX University in XXXX', ' however. The XXXX University Financial Aid Office was horrifically inept and even though I regularly tried to contact them', 1),
#  (' I feel sure this is a scam', None, 1),
#  (" I filed a inquiry to XXXX to clarify what had happened and to ask for a refund. On XXXX/XXXX/16 I received this response : I 'm sorry if the fee was ... (53 characters truncated) ...  certainly research if this is an issue on our end or deluxe. You may return the checks to your nearest branch at usbank.com/locations. In the future", None, 1),
#  (' I finally got a human on the line. She sounded XXXX and did not grasp that this was a fraudulent use of my account until I pointed that out to her. She said she would get the charges removed from my account and would also cancel it', None, 1),
#  (' I finally got the funds on Thursday', None, 1),
#  (' I first purchased my home by signing a home loan with XXXX and was immediately transferred to Wells Fargo Bank. I paid my mortgage as agreed on time for years. However', None, 1),
#  (' I followed further instructions from my supposed new employer to send XXXX wire transfers for {$800.00} and {$900.00} to XXXX', 'CA', 1),
#  (' I forgot to cancel the service prior to it converting into a recurrent billing subscription. After noticing the charges a month or two later I conta ... (138 characters truncated) ... acted them again and when that did not work I closed my bank account and opened a new account to prevent any further unscrupulous charges. Last night', ' requesting a cancellation payments have always stopped so I have never needed to ever call Paypal with a problem. Needless to say', 1),
#  (' I found that Discover had a department called the "" Executive Office of Customer Advocacy. \'\' I thought this dept would handle my concern in a more "" independent \'\' manner', None, 1),
#  (' I found the XXXX XXXX XXXX XXXX \'Welcome Letter \' mixed in with some junk mail that was sitting on my office desk - I was in the process of accumulating various numbers for my XXXX Tax return."', 'Web', 1),
#  (' I got an alert ( Through an ID monitoring service ) that my credit report had a hard inquiry twice', None, 1),
#  (' I guess to prevent customer complaints. And it is not working for many days now', 'Consent provided', 1),
#  (' I had 9 months before that was to begin. RMS has made a complete mess out of this seemingly easy transaction and with no legal oversight by state and federal regulators', None, 1),
#  (' I had approximately 15 months remaining on my business locations lease and certainly informed him of that fact. I also mentioned that I wanted to save approximately XXXX dollars per month with any new agreement', None, 1),
#  (' I had come to find out this had happened again when Sallie Mae was asking for the upcoming XXXX payment. I called Sallie Mae to figure out what was  ... (198 characters truncated) ...  I then asked that enough money be taken out of the overflow account to pay for any outstanding payments ( XXXX and XXXX payments ) for the XXXX loan', None, 1),
#  (' I had defaulted on XXXX my smaller loans. The loan did get paid off but this has effected my credit score as well as my parents and when trying to t ... (308 characters truncated) ... . When asked if the terms could be changed or allowed for my cosigner parents to be released from my loans after so many consecutive on time payments', None, 1),
#  (' I had exceptional credit score', None, 1),
#  (' I had gone into a Chase bank branch and followed instructions to withdraw my cash from my checking/savings account', None, 1),
#  (' I had made XXXX successful payments on time with this current loan', None, 1),
#  (' I had some extraordinarily large bills to pay. Car registration', ' threatening letter from a XXXX XXXX', 1),
#  (" I had to cancel that dispute. It will come out of my account tomorrow and I 'll be negative", None, 1),
#  (' I had to verify the last XXXX of my SS. Then the man ( XXXX XXXX ) said I took out a payday loan in XXXX 2013 from XXXX XXXX', '782XX', 1),
#  (' I have XXXX requests. First', None, 1),
#  (' I have also been inundated with emails from Western Union and others. If I recall', None, 1),
#  (' I have asked among other things in my day XXXX/XXXX/XXXX dispute a copy of the contract signed by my accepting the terms and conditions of these bills and my obligation to pay a bill it is not proof of debt', ' any document without my signature lacks validity', 1),
#  (' I have asked and told them to STOP calling me', None, 1),
#  (' I have asked time and time again for account loan data from original lender and the debt collector refused yet they are continuing to threaten to st ... (98 characters truncated) ... ing further injury to me and my family. Altisource has called me numerous times and has called relatives and discussed with them our private business', 'Consent provided', 1),
#  (' I have been asking for my Mortgage Loan review for the past one year now', None, 1),
#  (' I have been communicating on many occasions about issues with payment transaction issues. Each and every time I have communicated with your organization', None, 1),
#  (" I have been denied access to speak directly to the CITIBANK 'S legal department and have been", None, 1),
#  (' I have been depleting what little retirement I had from my Mutual funds and IRA to be able to meet living expenses. At this rate', None, 1),
#  (" I have been paying extra on my car loan since we purchase the car in XXXX XXXX XXXX XXXX. The question I have is my payment is XXXX and my loan paym ... (296 characters truncated) ...  will credit XXXX out of a payment of XXXX and the answer is they carry that overpayment forward and I ask why do n't they apply some to the interest", None, 1),
#  (' I have cried', None, 1),
#  (' I have enclosed the XXXX Cancelling the debt. Please delete this account XXXX XXXX', None, 1),
#  (' I have finally had an opportunity to speak with XXXX and get to the increase in closing costs. Our initial interview was on XXXX/XXXX/XXXX. At that time I was calculating the Tax Transfer Fee to be a common and customary fee 100 % paid by for by the seller. XX/XX/XXXX', None, 1),
#  (" I have n't received a letter", None, 1),
#  (" I have never been given any kind of credit unless I asked for it and filled out a credit application. How can PayPal be allowed to get away with this scam? I 've been using PayPal for years. If they 've done something to their check out process to make PayPal Credit the default", None, 1),
#  (' I have never heard from any of them. I will attach the docs that show the tax releases. I hope you can help me', None, 1),
#  (' I have no obligation to XXXX since XXXX lnXXXX', ' her pay was reduced. XXXX staff advised that we could restructure the loan slightly so she could make payments. I helped her with several payments as we waited for XXXX to work with us. Rather suddenly', 1),
#  (' I have no other choice that make my complaint more public and request escalation on this case."', 'Web', 1),
#  (' I have proven your records are inaccurate compared to the financial institution transactions', None, 1),
#  (' I have received XXXX calls', None, 1),
#  (' I have received XXXX curb appraisals from Wells Fargo Bank', ' XXXX Wells Fargo sent out a 30 day notice to pay my past due amounts owed', 1),
#  (' I have received over 50 calls from this number XXXX. When I pick up the phone', None, 1),
#  (' I have requested a complete detailed explanation of the current deficiency which has gone unanswered. I believe the current monthly payment is also incorrect and does not reflect the terms in both the Truth in Lending Statement as well as the actual terms of the Adjustable Rate Note."', 'Web', 1),
#  (" I have searched the Federal Housing Administration 's ( FHA ) website", None, 1),
#  (' I have shared my bank statement ( attached ) showing the XXXX {$200.00} transactions and XXXX {$100.00} transactions as well as the recovery of XXXX ... (60 characters truncated) ... t in their system they showed XXXX {$200.00} transactions on XXXX however their system rejected XXXX {$200.00} payment and it went back to the source', None, 1),
#  (" I have since I was XXXX I 'm now XXXX the close of escrow is XXXX - this house was the perfect house for my husband who is XXXX", None, 1),
#  (' I have since put a stop payment on all my automatic-bill transactions', ' when all I had to do was give the bank what I actually owe them', 1),
#  (' I have spoken to several Barclay representatives', None, 1),
#  (' I have submitted information to remove the XXXX addresses that are not associated with me', None, 1),
#  (' I have tried to contact them directly and through the Credit Bureau', None, 1),
#  (' I have tried working out payments with Navient', None, 1),
#  (' I have without fail made monthly and timely in-person payments on both accounts', ' despite verbal confirmation I received from Brown subsequently', 1),
#  (' I headed to a Wells Fargo branch in XXXX XXXX', None, 1),
#  (" I honestly believe Chase 's practice of clearing pending charges at XXXX at night and then having any direct deposit come in shortly after XXXX is an Unfair", None, 1),
#  (' I in no way was expecting to be relieved of my responsibility for the balance', None, 1),
#  (' I just called - and an employee said I needed to talk to someone in customer service. They gave me the telephone number', None, 1),
#  (' I kept getting AUTO GENERATED letters that information was verified with the furnisher thus it should stay on the record. When contacted furnisher-  ... (26 characters truncated) ... alifornia-they confirmed in writing that they DO NOT REPORT OR VALIDATE any information to none of the bureaus ... VERIFICATION BY EXPERIAN WAS A LIE', None, 1),
#  (' I know I qualify for a Loan Modification', None, 1),
#  (' I learned about "" insufficient funds \'\' fees and how those are different than "" overdraft fees \'\'. If you pay some of your monthly bills automatically', None, 1),
#  (' I learned that the mortgage company has had an expired license since 2009. Then I asked the licensed real estate agent who did the paperwork in the  ... (233 characters truncated) ... ts on people. CREDCO has not responded to my email about it. It seems to me that CREDCO should know whether or not its customers are even in business', None, 1),
#  (' I left XXXX yet another voice mail sharing my expectation that the funds were back in my hands by the end of the week. I received neither a response nor the check. When I called today', None, 1),
#  (' I made a purchase in XXXX', None, 1),
#  (' I met with assistant store manager', None, 1),
#  (' I never received any bill for this service until now', None, 1),
#  (' I never received the XX/XX/XXXX statement so no payment was made. When the next statement came it had penalty and interest so i called to find out why and discovered the missing statement', None, 1),
#  (' I overpaid {$200.00} in response to Synchrony \'s demand for {$110.00} to allegedly bring my account "" current', ' Account XXXX', 1),
#  (' I paid the XXXX dollars to get this lifted on XXXX/XXXX/2016 and then they XXXX XXXX can back and said they could run file because I had a federal fraud alert on my phone number. My phone number was not listed in my file', None, 1),
#  (' I pity the less sophisticated', '681XX', 1),
#  (' I provided Experian a copy of a government identification', None, 1),
#  (' I provided the requested information to TSI', None, 1),
#  (' I pulled XXXX and XXXX as well. Sure enough', 'Collections Acquisition Company, Inc.', 1),
#  (' I pulled up my account online and saw that there was a fraudulent hold placed on my account as I was overseas. Called citibank and spoke to different consultants and managers but no ones seems to know how to help me. They ask me for my personal informations like account password', None, 1),
#  (' I put an offer on a house. It was a XXXX foreclosure home owned by the XXXX XXXX. After many transfers of paperwork and paying for home inspections', " there are too many repairs for the bank that is approving your loan to deal with ''. So I lost the house and money I spent on everything to get it approved At that point the vacation rental was already overdue for me to move out", 1),
# ...
#  (' XXXX. The XXXX website says that based on this date', None, 1),
#  (' XXXX. This is to advise you that despite the fact that YOU have received a response from Wells Fargo', ' do you do anything to justify your existance? Do you do any independent investigation of complaints? So in addition to my complaint against Wells Fargo', 1),
#  (" XXXX. XXXX for collections and they could provide no further info and that I 'd have to contact them ( XXXX ). I then made contact with XXXX the same day", ' Contact Us and Profile', 1),
#  (' XXXX/XXXX/16', None, 2),
#  (' XXXX/XXXX/2016', None, 2),
#  (' XXXX/XXXX/XXXX', None, 7),
#  (' XXXX/XXXX/XXXX', 'Company believes it acted appropriately as authorized by contract or law', 1),
#  (' XXXX/XXXX/XXXX and on Saturday', None, 1),
#  (' Your lawyer can request invoices', None, 1),
#  (' a XXXX mortgage', None, 1),
#  (' a banking institution with operations all over the world', None, 1),
#  (' a checked was bounced on me which caused my bank to bounce a check to Citicorp for payment on my credit card. I let them know in advance', None, 1),
#  (" a corrected bill will be sent. '' 4. In a new bill", None, 1),
#  (' a cosigner', None, 1),
#  (' a debt collector shall', ' or any portion thereof', 1),
#  (' a division of Hyundai Capital America ( "" HCA \'\' ) engaged in illegal', None, 1),
#  (' a look at the actual XXXX data provided by the XXXX XXXX XXXX XXXX clearly shows that the XXXX has been *decreasing* since the middle of XXXX', None, 1),
#  (' a money line of credit', None, 1),
#  (' a plummeting credit profile', None, 1),
#  (' a provider of legal services to the mortgage bankingIndustry', None, 1),
#  (' a representative told me that I was eligible for further 2 month forbearance on each loan. I called today to arrange these forbearances', None, 1),
#  (' a service does not have the rights of a holder in due course and therefore', None, 1),
#  (' about a year ago', None, 1),
#  (' access to a computer', None, 1),
#  (' according to internet search ) about unknown person. Nobody at our number ( XXXX ) has any debt and we are on the Do Not Call List. The robo-call leaves a message to call XXXX about XXXX (? ) XXXX (? ) a name we have no knowledge of. The company calls late at night', None, 1),
#  (' account type', None, 1),
#  (' accounts to claim full responsibility on', None, 1),
#  (' actual damages sustained by the consumer as a result of the failure or {$1000.00}', '', 1),
#  (' address', None, 1),
#  (' addresses', None, 1),
#  (' advice of counsel', ' \'\' Wells Fargo stated. "" However', 1),
#  (' after I refused to give my SSN but did give the rep the account number which was on the card', None, 1),
#  (' after along hold the associate told us the deposit transfer would take 2 days not 24hrs', None, 1),
#  (' after making big payments for a few years', None, 1),
#  (" after over two months of discussions -- Citi 's mortgage broker announced that our income was insufficient to qualify for both mortgages at once. ( Not insufficient for either loan", None, 1),
#  (' after reconfirming eligibility and terms via REST Report/Loan Disposition Analysis/NPV', None, 1),
#  (' after repeatedly calling Chase to confirm the payment amount. Thanks to the brilliant idea of a verbal mortgage! Our records also confirm that we first tried to make the second payment on-line but when it was not accepted', None, 1),
#  (' after speaking with XXXX XXXX XXXX ( did not have an offer for the property', None, 1),
#  (' after this Complaint to your agency', None, 1),
#  (' after this payment my account balance became XXXX . At XXXX/XXXX/2016 I called to costumer service by number XXXX', None, 1),
#  (' again', None, 2),
#  (' again this year they always have for the 3 years I have been with them. Ever since I have been with Quicken loans insurance agent has called me conc ... (262 characters truncated) ... s that it has been paid but it has not. One of the employees at QL did pass on to me that they use a 3 rd party vendor to pay all taxes and insurance', None, 1),
#  (' agony and negative reflection this has caused is unacceptable', None, 1),
#  (' all he can do is give me his business card with a note saying he had this discussion with me ; he gave me his card and dated and sign that he had the discussion with me. He then recommended that I go to my Bank', None, 1),
#  (' all individuals named below are CapitalOne employees ) : XXXX XXXX 2016 : I opened a savings account to capitalize on a "" new customer \'\' bonus ( {$500.00} ) advertised as being available 90 days after opening a savings account. I am informed CapitalOne "" prefers \'\' ( i.e.', None, 1),
#  (' all information', None, 1),
#  (' all via phone. Each time', ' but no calculations as to how that amount was determined. So far', 1),
#  (' almost all making serious criticism of HSBC', None, 1),
#  (' along with XXXX that put the pressure on us and refused to speak with me', None, 1),
#  (' along with XXXX {$120.00} late fees. That is wrong', None, 1),
#  (' along with proof of all owners from each subsequent transaction made when the note was packaged and sold and resold to investors who made investment decisions based on the packaged mortgage backed securities being represented to them that there was', None, 1),
#  (' although I was able to get out of my counseling job paying {$13.00} an hour after 12 years of service with that agency', ' I found a roommate to share expenses a month ago', 1),
#  (' although nowhere on the bill does it state that the closing date is the actual date on which the bill is printed. At minimum', None, 1),
#  (' among these account XXXX them was with bank of America. I had immediately contacted the credit bureaus and had notified them about my identity was s ... (317 characters truncated) ... f America that been giving me the run around for the past two and half years. I had send them the following letter certified mail more than ten times', None, 1),
#  (' amount', None, 2),
#  (' an identifier or their last name. However', None, 1),
#  (" an important buyers ' feature in XXXX XXXX XXXX XXXX XXXX ii", None, 1),
#  (' an incomplete account number and many pages of generic documents that did not apply to the case at all. Prior to court', None, 1),
#  (' and', None, 1),
#  (' and Chase the resolved the issue then', None, 1),
#  (' and I am forwarding this information to my Senator XXXX XXXX', None, 1),
#  (' and I believe that the note and security instrument were sold already', None, 1),
#  (' and I demanded my promisary note and proof of payments made since XX/XX/XXXX ( see attached ). AES continued to send me a bunch of nonsense regarding a "" deferment \'\' and a "" forbearance \'\' on my loan ... none of which I initiated. XX/XX/XXXX', None, 1),
#  (" and I faxed her copes of my information. XXXX followed up with XXXX XXXX and the bank 's legal department", ' and still do', 1),
#  (' and I found out that Syndicated Office Systems ( whom also goes by Central Financial Control ) put my account to collection. I called the phone # listed within my credit report', None, 1),
#  (' and I have had a difficult time coming to grips with the result of part of the outcome since. I am an honest hard working person', None, 1),
#  (" and I have recepts of checks that are not listed on payment history that I did n't receive credit for and Ocwen has the proof", None, 1),
#  (" and I was getting help from the bank 's VP. I was telling her about my situation and she suggested that I write you. She told me that you are a nice and understanding man. XXXX XXXX", None, 1),
#  (' and Insurance documents. XXXX providing information that this car is garaged at her home address "" a senior housing complex \'\' XXXX continues to report that I am a cosigner on this account the most compelling evidence', None, 1),
#  (' and SunTrust agreed', ' and landlords may not discriminate on the basis of race and national origin ( the Act also prohibits discrimination based on sex', 1),
#  (' and TransUnion continues to list the disputed item on my credit report I will find it necessary to sue you for actual damages and declaratory relief under the FCRA. According to this regulation', None, 1),
#  (' and TransUnion have come back to me and stated they were able to verify these inaccurate accounts. How is this possible? Under the laws of the FDCPA', None, 1),
#  (' and XXXX as a partial payment toward this month. See other email I sent to your company today for further explanation', None, 1),
#  (' and accecpted by', '', 1),
#  (" and after substantiating borrower 's default and servicer 's right to foreclose. XXXX XXXX b ). They violated the National Mortgage Settlement guidelines XXXX", None, 1),
#  (' and all accounts thereof are accepted for value', None, 1),
#  (' and also found out that XXXX XXXX is not an attorney as he told me he was. This evening', None, 1),
#  (' and also told them to contact the person and get their correct information', None, 1),
#  (' and always have been', None, 1),
#  (' and am not getting anywhere with it. The seller has also quit responding to all of my emails. I am about to close my PayPal account', 'Consent provided', 1),
#  (' and any remaining balance would be forgiven. I did as you asked. It now appears that you have failed', None, 1),
#  (' and being that he is the professional', None, 1),
#  (' and can not according to XXXX - as this data is not expected to be sent by a debt collector on this industry standard file. I have never been late with XXXX nor XXXX 8. XXXX account on EQ is reporting a creditor classification of "" RETAIL \'\' and can not', None, 1),
#  (' and confusion with my transactions. All in which were proven beyond my control', None, 1),
#  (' and during the deferral period before that', None, 1),
#  (' and enter an amount to pay', None, 1),
#  (' and extended family members', None, 1),
#  (" and found many customers have had issues with XXXX XXXX ' not honoring sign-up bonuses", None, 1),
#  (" and frustrating my lawful efforts to close my Father 's accounts. I am hoping CFPB can compel Bank of America to take my concerns seriously", None, 1),
#  (' and had no intention of honoring its agreement. I am aware that Midland records all of its phone calls', 'Consent provided', 1),
#  (' and have added it to my Trans Union and XXXX credit reports as a brand new Unpaid Charge Off Debt', None, 1),
#  (' and have been found that XXXX was one of their biggest profit makers', None, 1),
#  (' and have been told that', None, 1),
#  (' and he assured me they would handle it at XXXX. When I called THAT number', None, 1),
#  (' and how to proceed if you do n\'t think you owe the money. The last option was not give to me. Both companies attempted to hide information from the ... (304 characters truncated) ... ose the account so no one else can attempt to collect the debt in which both companies violated debt collection practices laws and arbitration laws."', 'Web', 1),
#  (' and if she will furnish our office what the dispute is', None, 1),
#  (' and if so', None, 1),
#  (' and if your Agency fails to find probable cause', None, 1),
#  (' and in the order they occurred', None, 1),
#  (' and its Pay Status', 'Consent provided', 1),
#  (' and last', None, 1),
#  (' and let me know. I had no problem getting the same from XXXX and XXXX. Thanks', 'Consent provided', 1),
#  (' and letters', None, 1),
#  (' and many times completely inaccurate information. Aside from the moral obligation', 'Consent provided', 1),
#  (' and marketing loan products to avoid and thereby discourage prospective borrowers in predominantly XXXX and XXXX neighborhoods in at least XXXX Metropolitan areas. Wells Fargo has a history of case management procedures which are wrong and illegal. During the relevant period', None, 1),
#  (' and moneys to purchase property. Realtor representing seller knew that property was not eligible for sale on XXXX XXXX 2016 when listed for sale and on XXXX XXXX', '782XX', 1),
#  (' and my loan payment is still pretty high', None, 1),
#  (' and no results provided. I called the hospital and they had no records of any lab work. The debt was only {$170.00} and now my credit score has take ... (107 characters truncated) ...  into it. I was unaware they reported it because other than the second letter they sent me which only contained a print out of medical coding screens', None, 1),
#  (' and not Current in its PAY STATUS 3. This account is missing Pay History 4. This account is missing Balance History 5. Please validate this account', 'Consent provided', 1),
#  (' and not serve the public."', 'Web', 1),
#  (' and noticed that Chase made incorrect calculations. On the application', None, 1),
#  (' and now they just filed a judgement of debt for {$220.00}', None, 1),
#  (' and on page XXXX', None, 1),
#  (' and once again we did not receive a detailed reason for the denial', None, 1),
#  (' and only received XXXX TPP under HAMP. He further meets all basic criteria for HAMP eligibility as outlined in section XXXX', None, 1),
#  (' and other information incorrect in my IDENTIFICATION VERIFICATION."', 'Web', 1),
#  (' and please correct the Activity designator to "" CLOSED \'\' - Willfully violate obligations under the FCRA', '', 1),
#  (" and prevent me from paying it off early. Why would an account like 'unapplied amount ' even exist? Except to criminally hold my money", None, 1),
#  (' and protect consumers from this predatory abuse', None, 1),
#  (' and requested an appeal or other process to reduce what I am being told is a mandatory minimum payment to "" Rehabilitate \'\' the Loan. The student loan manager emailed me back stating that the collection agency is correct', None, 1),
#  (' and seems to be a matter of unfair', None, 1),
#  (' and she said it takes 10 business day for a reply to be generated - it would have been nice if the person that answered my first call would have said that', None, 1),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 13 y ... (16 characters truncated) ...  no Balance History in this account - and there should be as this account was opened for over 13 years 4. Because this account has no Payment History', None, 2),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 3 ye ... (14 characters truncated) ... s no Balance History in this account - and there should be as this account was opened for over 3 years 4. Because this account has no Payment History', None, 3),
#  (' and since then I have been unable to find any. I am living with my mother for the first time in a decade', None, 1),
#  (' and spoke and received letters from BOA executive office and NO ONE offered me the core account. NO ONE! This would have been a very easy fix as I already had direct deposit anyway!!! I am so mad that all I received was explanations and copies of my CM agreement', ' commended for great customer service and some knowledge about the accounts. Maybe she should be in the executive office! Please', 1),
#  (' and spoke to XXXX ( Customer Service Agent ) who completely refused to help. I then asked to speak to a supervisor', None, 1),
#  (' and still', None, 1),
#  (' and still be able to provide the beneficiary with a XXXX repayment', None, 1),
#  (' and temperatures in the XXXX', ' and found someone with a truck to tow me into town. One week later I was able to charter a flatbed truck passing down the road on its way to XXXX', 1),
#  (' and that I had no reason to anticipate such blatant disregard for my time and situation. Travel plans have had to be postponed due to these unjustified delays', ' but merely designed to take advantage of their customers during a time when cooperation from their lender is most needed. It is a shameful and demeaning way to operate a business."', 1),
#  (' and that I need to pay in order for them to do anything', 'Consent provided', 1),
#  (' and that his communication was an attempt to collect a debt', None, 1),
#  (' and that is NOT LAWFUL! I have no proof', None, 1),
#  ...]

# %% [markdown]
# ### (c) Covering indexes (10 puntos)
#
# A continuación investigue y describa qué es un _covering index_ y defina un _convering index_ que cubra el query anterior:
#
# Un index donde todas la columnas existen y en el caso de sql se optimisa para que no se tenga que acceder a las filas de la tabla

# %%
# %%sql
# DROP INDEX IF EXISTS cover;
# CREATE INDEX cover
#     ON complaints
#      ( Product, State );
# Out:
#  * sqlite:///complaint.db
# Done.
# Done.
# []

# %% [markdown]
# Ejecute nuevamente su query inicial para verificar que el tiempo de respuesta mejoró:

# %%
# %time %sql SELECT Product,State,count(*) FROM complaints GROUP BY Product, State
# Out:
#  * sqlite:///complaint.db
# Done.
# Wall time: 46.9 ms
# [(None, None, 13451),
#  ('', None, 1),
#  ('', '01/01/2016', 1),
#  ('', '01/02/2016', 7),
#  ('', '01/03/2016', 9),
#  ('', '01/04/2016', 17),
#  ('', '01/05/2016', 16),
#  ('', '01/06/2016', 19),
#  ('', '01/07/2016', 26),
#  ('', '01/08/2016', 17),
#  ('', '01/09/2016', 6),
#  ('', '01/10/2016', 8),
#  ('', '01/11/2016', 23),
#  ('', '01/12/2016', 23),
#  ('', '01/13/2016', 17),
#  ('', '01/14/2016', 19),
#  ('', '01/15/2016', 25),
#  ('', '01/16/2016', 6),
#  ('', '01/17/2016', 8),
#  ('', '01/18/2016', 12),
#  ('', '01/19/2016', 12),
#  ('', '01/20/2016', 27),
#  ('', '01/21/2016', 22),
#  ('', '01/22/2016', 15),
#  ('', '01/23/2016', 6),
#  ('', '01/24/2016', 4),
#  ('', '01/25/2016', 10),
#  ('', '01/26/2016', 36),
#  ('', '01/27/2016', 29),
#  ('', '01/28/2016', 26),
#  ('', '01/29/2016', 19),
#  ('', '01/30/2016', 6),
#  ('', '01/31/2016', 4),
#  ('', '02/01/2016', 26),
#  ('', '02/02/2016', 20),
#  ('', '02/03/2016', 26),
#  ('', '02/04/2016', 22),
#  ('', '02/05/2016', 20),
#  ('', '02/06/2016', 12),
#  ('', '02/07/2016', 8),
#  ('', '02/08/2016', 16),
#  ('', '02/09/2016', 19),
#  ('', '02/10/2016', 25),
#  ('', '02/11/2016', 16),
#  ('', '02/12/2016', 24),
#  ('', '02/13/2016', 7),
#  ('', '02/14/2016', 9),
#  ('', '02/15/2016', 5),
#  ('', '02/16/2016', 13),
#  ('', '02/17/2016', 25),
#  ('', '02/18/2016', 33),
#  ('', '02/19/2016', 29),
#  ('', '02/20/2016', 10),
#  ('', '02/21/2016', 8),
#  ('', '02/22/2016', 26),
#  ('', '02/23/2016', 17),
#  ('', '02/24/2016', 31),
#  ('', '02/25/2016', 17),
#  ('', '02/26/2016', 24),
#  ('', '02/27/2016', 13),
#  ('', '02/28/2016', 6),
#  ('', '02/29/2016', 12),
#  ('', '03/01/2016', 29),
#  ('', '03/02/2016', 22),
#  ('', '03/03/2016', 20),
#  ('', '03/04/2016', 19),
#  ('', '03/05/2016', 11),
#  ('', '03/06/2016', 12),
#  ('', '03/07/2016', 17),
#  ('', '03/08/2016', 35),
#  ('', '03/09/2016', 22),
#  ('', '03/10/2016', 21),
#  ('', '03/11/2016', 22),
#  ('', '03/12/2016', 11),
#  ('', '03/13/2016', 7),
#  ('', '03/14/2016', 14),
#  ('', '03/15/2016', 27),
#  ('', '03/16/2016', 23),
#  ('', '03/17/2016', 21),
#  ('', '03/18/2016', 16),
#  ('', '03/19/2016', 7),
#  ('', '03/20/2016', 5),
#  ('', '03/21/2016', 19),
#  ('', '03/22/2016', 31),
#  ('', '03/23/2016', 20),
#  ('', '03/24/2015', 1),
#  ('', '03/24/2016', 21),
#  ('', '03/25/2016', 19),
#  ('', '03/26/2015', 1),
#  ('', '03/26/2016', 13),
#  ('', '03/27/2016', 3),
#  ('', '03/28/2016', 22),
#  ('', '03/29/2016', 26),
#  ('', '03/30/2016', 20),
#  ('', '03/31/2016', 10),
#  ('', '04/01/2015', 1),
#  ('', '04/01/2016', 25),
#  ('', '04/02/2016', 11),
#  ('', '04/03/2016', 10),
#  ('', '04/04/2016', 25),
#  ('', '04/05/2016', 25),
#  ('', '04/06/2016', 25),
#  ('', '04/07/2015', 1),
#  ('', '04/07/2016', 19),
#  ('', '04/08/2016', 24),
#  ('', '04/09/2016', 10),
#  ('', '04/10/2016', 3),
#  ('', '04/11/2016', 27),
#  ('', '04/12/2016', 30),
#  ('', '04/13/2015', 1),
#  ('', '04/13/2016', 22),
#  ('', '04/14/2016', 17),
#  ('', '04/15/2016', 20),
#  ('', '04/16/2015', 2),
#  ('', '04/16/2016', 6),
#  ('', '04/17/2016', 7),
#  ('', '04/18/2016', 18),
#  ('', '04/19/2016', 22),
#  ('', '04/20/2015', 1),
#  ('', '04/20/2016', 20),
#  ('', '04/21/2016', 21),
#  ('', '04/22/2016', 18),
#  ('', '04/23/2016', 9),
#  ('', '04/24/2016', 5),
#  ('', '04/25/2016', 13),
#  ('', '04/26/2016', 8),
#  ('', '04/27/2016', 23),
#  ('', '04/28/2016', 19),
#  ('', '04/29/2015', 1),
#  ('', '04/29/2016', 24),
#  ('', '04/30/2015', 1),
#  ('', '04/30/2016', 5),
#  ('', '05/01/2016', 5),
#  ('', '05/02/2016', 23),
#  ('', '05/03/2016', 26),
#  ('', '05/04/2016', 18),
#  ('', '05/05/2016', 21),
#  ('', '05/06/2016', 15),
#  ('', '05/07/2016', 2),
#  ('', '05/08/2016', 9),
#  ('', '05/09/2016', 17),
#  ('', '05/10/2016', 23),
#  ('', '05/11/2016', 20),
#  ('', '05/12/2015', 1),
#  ('', '05/12/2016', 14),
#  ('', '05/13/2016', 10),
#  ('', '05/14/2016', 12),
#  ('', '05/15/2015', 1),
#  ('', '05/15/2016', 1),
#  ('', '05/16/2016', 10),
#  ('', '05/17/2016', 7),
#  ('', '05/18/2016', 19),
#  ('', '05/19/2016', 10),
#  ('', '05/20/2015', 1),
#  ('', '05/20/2016', 8),
#  ('', '05/21/2016', 6),
#  ('', '05/22/2015', 1),
#  ('', '05/22/2016', 4),
#  ('', '05/23/2016', 12),
#  ('', '05/24/2016', 6),
#  ('', '05/25/2016', 8),
#  ('', '05/28/2015', 1),
#  ('', '06/03/2016', 1),
#  ('', '06/07/2016', 1),
#  ('', '06/10/2016', 1),
#  ('', '06/14/2016', 1),
#  ('', '06/15/2016', 2),
#  ('', '06/21/2016', 1),
#  ('', '06/24/2015', 1),
#  ('', '06/25/2015', 1),
#  ('', '06/30/2015', 1),
#  ('', '07/13/2015', 1),
#  ('', '07/14/2015', 1),
#  ('', '07/17/2015', 1),
#  ('', '08/08/2015', 1),
#  ('', '08/12/2015', 1),
#  ('', '09/02/2015', 1),
#  ('', '09/24/2015', 1),
#  ('', '09/30/2015', 1),
#  ('', '10/20/2015', 1),
#  ('', '10/27/2015', 1),
#  ('', '11/12/2015', 1),
#  ('', '11/18/2015', 1),
#  ('', '11/20/2015', 1),
#  ('', '12/02/2015', 8),
#  ('', '12/07/2015', 2),
#  ('', '12/08/2015', 15),
#  ('', '12/09/2015', 12),
#  ('', '12/11/2015', 1),
#  ('', '12/12/2015', 10),
#  ('', '12/13/2015', 7),
#  ('', '12/14/2015', 12),
#  ('', '12/15/2015', 14),
#  ('', '12/16/2015', 18),
#  ('', '12/17/2015', 9),
#  ('', '12/18/2015', 20),
#  ('', '12/19/2015', 3),
#  ('', '12/20/2015', 5),
#  ('', '12/21/2015', 16),
#  ('', '12/22/2015', 10),
#  ('', '12/23/2015', 14),
#  ('', '12/24/2015', 11),
#  ('', '12/26/2015', 5),
#  ('', '12/27/2015', 3),
#  ('', '12/28/2015', 19),
#  ('', '12/29/2015', 9),
#  ('', '12/30/2015', 12),
#  ('', '12/31/2015', 15),
#  ('', 'Consent not provided', 2),
#  ('  a TSYS Company"', 'Closed with explanation', 3),
#  ('  a TSYS Company"', 'Closed with monetary relief', 1),
#  (' "" ACCORDING TO THEIR SCHEDULE \'\'', None, 1),
#  (' "" Amount Due \'\' of : {$1100.00} XXXX XXXX', None, 1),
#  (' "" I understand you are upset because you were n\'t offered some sort of physician discount. \'\' Nope', None, 1),
#  (' "" Once the property is sold and the debt is paid', ' for servicing. Immediately after the financial meltdown of XXXX', 1),
#  (' "" Once your 90 day waiting period is complete', None, 1),
#  (' "" Our records indicate you have not made your last four or more regularly scheduled payments. Subject to applicable law', " we are offering you an opportunity to enter into a Trial Period for a loan modification ... '' I have in fact made payments for the entire time peri ... (156 characters truncated) ... merous Bank of America personnel in various departments ( See communication notes ) who transferred me back and forth between them with no resolution", 1),
#  (' "" They the agreed with PNC and are not changing the amount I owe. \'\' I also asked her to put how they came up with this agreement in writing and she said', 'Consent provided', 1),
#  (' "" Transactions should be processed in a neutral order that avoids manipulating or structuring processing order to maximize customer overdraft and related fees. Examples of a neutral order include order received', None, 1),
#  (' "" Which of these best describes your issue?', None, 1),
#  (' "" Who is XXXX? \'\' I asked him this because when the payments are taken out of my account my account shows the payments are going to a company named XXXX. XXXX XXXX told me his client was XXXX XXXX', None, 1),
#  (' "" XXXX XXXX', None, 1),
#  (' "" Yes. \'\' The man then said', ' "" No', 1),
#  (' "" Your creditor or debt collector believes that the legal time limit ( statute of limitations ) for suing you to collect this debt may have expired. It is a violation of the Fair Debt Collection Practices Act', None, 1),
#  (' "" how can a person who ca n\'t pay X', None, 1),
#  (' # XXXX', '705XX', 1),
#  (' # XXXX XXXX', None, 1),
#  (" '' 91 Stat. 874 ( XXXX )", 'OH', 1),
#  (" '' I do n't anticipate this complaint doing much good", None, 1),
#  (' \'\' and "" workout plans. \'\' We had made all of our payments on time. In another set of documents', ' we repeatedly called Bank of America for clarification', 1),
#  (" '' and my loan was magically put into forbearance. If the policy did in fact change the day after CFPB notified Wells Fargo of my complaint", None, 1),
#  (" '' and that they notified the other credit reporting agencies of the same information. I immediately called them", None, 1),
#  (' \'\' based ona "" range of potential losses for each matter that is both probable and estimable. \'\' Wells Fargo stated that the "" high end of the ... (12 characters truncated) ... asonably possible potential litigation losses in excess of the company \'s liability for probable and estimable losses was approximately {$1.00} XXXX', None, 1),
#  (" '' but when I asked why I never received a voice mail", None, 1),
#  (' \'\' or persons who furnish information to consumer reporting agencies ( "" CRA \'\' ) such as credit bureaus. In particular', None, 1),
#  (" '' that was purportedly signed by me", None, 1),
#  (" '' the CFPB said", None, 1),
#  (" '' which still leaves their prior negative information on my credit reports and negatively effects my credit scores. I was very specific in my request", None, 1),
#  (" 'executives ' are working on a lump sum settlement for all claims. Once a settlement is reached", ' a settlement', 1),
#  (' ( 6 months before it was due )', None, 1),
#  (' ( Credit Union ) response is that the information you have disputed is both true and correct according to all available documentation. As such', None, 1),
#  (' ( I was told that there was an issue with my expenses being too low and I was told that the underwriter took the initiative to calculate them at a higher amount even if they were not my actual expenses. ) XXXX XXXX', None, 1),
#  (' ( XXXX ) "" Seizures for Property \'\'', None, 1),
#  (' ( business plan', None, 1),
#  (' ( the settlement amount that I also have in canceled checks )', None, 1),
#  (' 1 week after yielding my physical address to AMEX', None, 1),
#  (' 12 CFR 226.15 ( b ) of Regulation Z states "" In any transaction or occurrence subject to rescission', None, 1),
#  (' 15 USC 1692', None, 1),
#  (' 2 months after closing my account and receiving a "" credit balance refund check. \'\' for {$2400.00} from them. May I please add that my account with them had a {$3000.00} CREDIT LIMIT! How can I possibly owe them {$600.00}?? Now my credit is being affected', None, 1),
#  (' 2013', None, 1),
#  (' 2015', None, 5),
#  (' 2015', 'Altisource Portfolio Solutions, S.à r.l.', 1),
#  (' 2015 ( relative to Nationstar/XXXX Notice of Debt Validation dated XX/XX/2015- with 30 day to validate debt ; then Nationstar violates FDCPA by recording the Notice of Default two days later', None, 1),
#  (' 2015 XXXX sent via email', None, 1),
#  (' 2015 by XXXX XXXX in XXXX', None, 1),
#  (' 2015 letter that FHA requires borrowers to provide a statement. I am providing documentation from FHA guidelines', None, 1),
#  (' 2015 not trying to validate the debt but to make a settlement offer', None, 1),
#  (" 2015 now through XXXX/XXXX/15. Rewards earned are in addition to your standard rewards and are added to your Miles account within 2 billing periods. ... (86 characters truncated) ... ged in deceptive marketing practices. They marketed a promotion promising amazing rewards with no cashback and after getting new customers to sign up", None, 1),
#  (' 2015 stating that I had to pay {$830.00} to cure the loan. Five days prior to the date of the letter I had already sent in a payment of {$820.00} via XXXX and then on XXXX XXXX', None, 1),
#  (' 2015. I provided a full written explanation and copies of the supporting evidence. As part of the investigation process', None, 1),
#  (' 2015. I think they are trying to collect for XXXX', None, 1),
#  (' 2015. The card has an annual fee of {$95.00} and it has an offer related to reimbursement of upto {$650.00} incurred towards purchase of new cellphone from AT & T provided new user spends {$2000.00} within 3 months. However', None, 1),
#  (' 2016', None, 7),
#  (' 2016 I contacted Commonwealth Financial Services to potentially pay off a debt. After talking with a lady who told me her name was XXXX XXXX we came ... (125 characters truncated) ... erification that the amount I was paying off was in writing. She emailed me XXXX verifications. I in return paid {$100.00} to settle a {$150.00} debt', None, 1),
#  (' 2016 I informed TD Bank that I was withdrawing my loan application due to their refusal to honor the terms of my original rate lock agreement. Due t ... (86 characters truncated) ... w lender I applied with sought an agreement to extend the deadline for the purchase and sales agreement between myself and the sellers. Unfortunately', None, 1),
#  (' 2016 I initiated an online dispute regarding the inaccurate reporting of inquiries and previous addresses on my Equifax file. Prior to that', None, 1),
#  (' 2016 I received a phone call stating that I received an {$8000.00} grant and in order to get the grant I had to give the account and routing number for my bank. The further instructions were to go to an ATM and pull out {$300.00}', None, 1),
#  (' 2016 I submitted a complaint to CFPB # XXXX "" Case number XXXX with response \'\'', None, 1),
#  (' 2016 I was notified on my online account that I was overdrawn. Knowing that I should have had funds I went online and checked and saw that Chase had reversed the credits from the dispute. This time instead of calling just the dispute center I called my local Chase Branch ( XXXX XXXX XXXX XXXX', None, 1),
#  (' 2016 TD Bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure indicated the correct loan', None, 1),
#  (' 2016 TD bank issued a loan disclosure for me to sign and return ( exhibit XXXX ). This disclosure again had the wrong terms', None, 1),
#  (' 2016 XXXX RESIDENT SCREENING Date : XXXX XXXX', ' 2016 XXXX XXXX XXXX Date : XXXX XXXX', 1),
#  (' 2016 are Attachments # XXXX "" BBVA XXXX XXXX XXXX letter-password reset \'\' and # XXXX "" BBVA deposit XX/XX/XXXX withdrawal XX/XX/2016.XXXX-balan ... (130 characters truncated) ...  Besides the absence of communication from the bank that results in lack of consumers knowledge of his account it shows contempt towards the customer', None, 1),
#  (" 2016. '' Recent phone calls from representative XXXX XXXX of the Collections Department of Navient Solutions ", None, 1),
#  (' 2016. \'\' Under the "" Address \'\' section of my "" Experian \'\' credit report it lists a false address of "" XXXX. XXXX XXXX ; XXXX', None, 1),
#  (' 2016. I have not received any documents."', 'Web', 1),
#  (' 3', None, 1),
#  (' 6 days after the XXXX due date. This meant that Wells Fargo \'s own process for refunding a payment that should have applied to XXXX would indeed ha ... (200 characters truncated) ... heir debts? I raised this question to the Wells Fargo staff who informed me this was "" just the way it is. \'\' To which I responded with skepticism', None, 1),
#  (' ALL INFORMATION OUTDATED SINCE 2005 AND ALL AGENCIES VIOLATES FCRA PROVISION XXXX', None, 1),
#  (" AND LACK OF GOOD FAITH IN YOUR DEALINGS WITH US AND OTHERS. ALL YOU EVER SEND TO US OR OUR STATE AND GOVERNMENT OFFICIAL 'S ARE OUR PAYMENT HISTORY", None, 1),
#  (' AND NEVER GOTTEN PROOF', None, 1),
#  (' ATTORNEY REPORTED MCCALLA RAYMER LLC WILL FILE SOMETHING CALLED CONTESTED MATTER TO RETURN TO COURT TO DISMM WHAT THEY CALL MOTION FOR RELIEF FROM A ... (192 characters truncated) ...  RELATED TO XXXX XXXX XXXX PAST XXXX AND MCALLA RAYMERS ASSOCIATES. CURRENTLY RECIEVING PREMISSION AND NOTARY STATEMENTS TO RELEASE THESE DOCUMENTS."', 'Web', 1),
#  (' Ally reposed the car from my mom place of residence. After the car was reposed by Ally', None, 1),
#  (' Alpha Recovery now has the debt and will not provide me with information nor have I been able to speak with someone who is reasonable and honest."', 'Web', 1),
#  (' Amazon', None, 1),
#  (" Amount Due '' of : {$1100.00}", None, 1),
#  (' Attorney -- -- -- -- -- -- -- -- -- -- -- -- -- - XXXX Virginia XXXX Office XXXX Mobile XXXX Mobile XXXX Email : XXXX XXXX ( Assistant ) -- -- -- -- -- -- -- -- - XXXX Non-Attorney Staff Member XXXX Virginia XXXX Office XXXX Fax XXXX"', 'Web', 1),
#  (' Attorney at Law', '02/05/2016', 1),
#  (' Authorized Representative', None, 1),
#  (' BANA has never merged with BofA Merrill Lynch Asset Holdings ', ' XXXX. CWHL', 1),
#  (' BB & T started adding additional fees to my note. They added the following fees : 1 ) {$1000.00} fee for XXXX appraisal fees -- why they would want  ... (64 characters truncated) ...  refinance is unexplainable. There is a provision in the contract that states if an appraisal is necessary I would be responsible for that fee. Again', None, 1),
#  (' BOA changed the property address to my XXXX home address and not my XXXX home address. The XXXX home is the collateral for a less than {$95000.00} modified equity line. In addition', None, 1),
#  (' BSI Financial Services', None, 1),
#  (' Bank of America. After a very frustrating process of them losing documents and re-asking for documents that I had already submitted', None, 1),
#  (' Barclaycard certified mail receipt and BarclaycardletterforACH ) because this account seems to have been confused and link to a bankruptcy that I fi ... (294 characters truncated) ... r pickup. I used the address provided by Barclay in the CFPB complaint response # XXXX at the bottom of their letter Card Services P.O. Box XXXX XXXX', None, 1),
#  (' Beal & Nixon', '02/25/2016', 1),
#  (' Bluebird XXXX XXXX XXXX XXXX XXXX XXXX', ' this bluebird account allows me to make deposits into my account easily but then they freeze my account every month while they verify everything."', 1),
#  (' BoA refuses to credit the {$38.00} because somewhere in a revised terms of service', None, 1),
#  (' BoA was never going to recoup the losses they assumed from Countrywide. As such', None, 1),
#  (' Branch Manager XXXX # XXXX HomeBridge Financial Services ', None, 1),
#  (' Burgess & Wolff', '12/21/2015', 1),
#  (" But did see on XXXX and all the inquires on Transunion credit. I know I have some outstanding debt. Probably close to XXXX with right XXXX price adj ... (449 characters truncated) ... t I would appreciate and cooperate in anyway for your help addressing these issues. Because I just do n't have the XXXX clarity to fight these issues", None, 1),
#  (' CA', None, 1),
#  (' CALIFORNIA XXXX TEL. NO ( XXXX ) XXXX', None, 1),
#  (' CMS guidelines also renders a loan ineligible to receive an alternative loan modification after receiving and defaulting under a HAMP Tier II TPP or a permanent HAMP Tier II loan modification under the same circumstances as outlined above. For this reason', None, 1),
#  (' Caliber Home Loans is and was', None, 1),
#  (' Case XXXX', None, 1),
#  (' Cash Advance Centers', '01/23/2016', 1),
#  (' Chase \'s counsel admitted that the denial was a "" streamline denial. \'\' She confirmed that the denial was not based on any information in the XXXX XXXX application because Chase had not actually reviewed it. The court directed that Chase review the XXXX XXXX application. On XXXX/XXXX/XXXX', None, 1),
#  (" Chase 's counsel emailed XXXX a letter denying XXXX for a Chase Modification", None, 1),
#  (' Chase XXXX', None, 1),
#  (' Chase did not correct the error', None, 1),
#  (' Chase was blaming the HOA first and', None, 1),
#  (" Citibank 's Illinois legal department refused the POA/XXXX submitted to the branch office. They instructed my cousin to call again or go to the XXXX XXXX in XXXX for notarization of there XXXX form", None, 1),
#  (' Citibank should be made to suffer the entire loss in the amount of {$1900.00}. Instead', None, 1),
#  (' Civil Code section 2923.5 requires lender to contact borrower in default and "" assess the borrower \'s financial situation and explore options for  ... (163 characters truncated) ...  CA. Homeowner Bill of Rights also provides that dual tracking protections can also protect homeowners who have been previously denied a modification', None, 1),
#  (' Complete and not in conflict with the account OPEN DATE and the CLOSURE DATE OR', None, 1),
#  (' Cruise and Smith LLC"', 'Untimely response', 1),
#  (' Customer Care 7 ) QUESTION FOR YOU : Am I not entitled to know how my bank uses ( lends or invests ) the money I deposit? Oil and gas is taking a huge hit right now and I want to know how my bank is exposed to losses. Is that not my right', None, 1),
#  (" DC also habitually charged late fees of {$39.00} even when I was n't late. I realize that they were doing this until after about a year of helping my mother-in-law when she passed away from XXXX. I called DC many times during my lunch break to have the late fees reimbursed. The refused. Finally", None, 1),
#  (" Debt collection agency. '' This is clearly confusing and misguiding consumers", None, 1),
#  (" Defendant 's principal place of businessis located at XXXX", None, 1),
#  (' Defendant filed a state court action againstPlaintiff on XXXX XXXX', None, 1),
#  (' Equifax ( r ) and XXXX ( r ) and any finance and other charges related to the fraudulent', None, 1),
#  (" Equifax is bounded in the terms set forth in the FCRA. Also let me remind you that under section 611 of the FCRA that you are required to investigate the completeness or accuracy of any item of information contained in a consumer 's file", None, 1),
#  (' Experian could not have conducted a reasonable reinvestigation to verify the accuracy of the disputed information. The FCRA clearly states that a cr ... (147 characters truncated) ... solely on hearsay information from the information source and shifted the burden back to me to contact the original creditor to verify these accounts', None, 1),
#  (' Experian has failed to complete their investigation within the 30-days', None, 1),
#  (' Experian has prevented Credit XXXX from getting my report and score. All info that I have provided to XXXX in XXXX has been exactly what I have given Experian when I obtained my free credit report today ( XXXX/XXXX/XXXX ). When I again tried CS today', None, 1),
#  (' Failed to show documentation that I have requested and failed to produce the note and Proof of Assignments to service my loan. XXXX also WILLINGLY and KNOWINGLY LIED ABOUT THE TRUSTEE AND OWNER OF THE NOTE by sending me the same LIE FILLED Note', None, 1),
#  (' Federal or CFPB guidelines. They think it is a joke."', 'Web', 1),
#  (' Florida has been contacted in each instance', None, 1),
#  (' From XXXX sent by wells Fargo in the year XXXX to us confirming the cancellation of this debt. Marked as XXXX ( This should have been done in the year XXXX and not in XXXX', None, 1),
#  (' GA XXXX \'\' Because the message is so vague ( "" a condition exists \'\' )', 'Consent provided', 1),
#  (' GA XXXX To whom it may concern : In accordance with Federal Civil Rights Law', None, 1),
#  (' GA XXXX"', 'Web', 1),
#  (' General Counsel for XXXX', ' legitimate cashier \'s checks bear the telephone number of the issuing institution ( which the counterfeit check did not ) and the check in question bore a suspicious "" security features box located on the reverse side. \'\' Therefore', 1),
#  (' Global Client Solutions', None, 1),
#  (' HSBC issued a response indicating the credit card account ending - XXXX is closed and that the credit will be deposited to my bank account. Please refer to Case number : XXXX. However', None, 1),
#  (' HUD', None, 1),
#  (" I 'm paraphrasing", None, 1),
#  (" I 'm sure you 'll want to handle this matter as soon as possible. For this purpose", None, 1),
#  (" I 've never had an XXXX account in my life but yet a debt of {$73.00} appears on my credit report", None, 1),
#  (" I 've resorted to filing this federal complaint due to the sinister organizational structure BofA has erected to try to get its customers to give up on collecting any checking account bonus due. I hope CFPB", None, 1),
#  (' I DEMAND ALL OF THEIR CLAIMS TO BE BACKED UP BY PRESENTING Convincing', None, 1),
#  (" I DEMAND that CHASE BANk 's credit reporting department", None, 1),
#  (' I HAVE TO GIVE UP THE RIGHT TO GO AFTER THE STOLEN MONEY AND LOOK FORWARD TO ONLY XXXX INSTEAD OF XXXX! BUT HOMELESS', None, 1),
#  (' I WAS DEFRAUDED BY BOTH THE VENDOR AND XXXX ... ... ..THE CREDIT REPORT DOES NOT CONTAIN A DOFD OF XX/XX/XXXX AS REQUIRED BY FCRA THE PAYMENT TABLE IS ERRONEOUS', ' WITH ME NOT PRESENT', 1),
#  (' I also bank here locally on the XXXX at XXXX bank. I keep my same old Chase bank account so I can send money to my grandmother who also banks there', ' the day my paycheck was projected to clear. That was the day Chase closed my account. As a result of the failed wire XXXX Checks I wrote bounced including the XXXX to court', 1),
#  (' I am', None, 1),
#  (" I am a victim of identity theft since XXXX 2015 and I have filed a police report for that submitting all evidences to the authorities. I have called ... (200 characters truncated) ...  have received a notice from my credit monitoring service that my credit score went down XXXX points in one shot! Checking my report to see the cause", None, 1),
#  (" I am away for the winter from the billing address and have not gotten Capital One 's last forwarded bill. However", None, 1),
#  (' I am disputing an account that I do not owe. The credit bureaus claimed the debt has been verified by IQ Data International. I call IQ Data Internat ... (67 characters truncated) ...  itemization. IQ data claims they do n\'t have it and could n\'t provide one anyways since they are not "" actively collecting the debt. \'\' However', None, 1),
#  (' I am furious', None, 1),
#  (' I am ineligible? That does not make any sense. It looks like a bait and switch to me."', 'Web', 1),
#  (' I am just shocked that Discover Card would treat a customer in this fashion. There is nothing "" negative \'\' that I have done wrong. Actually', None, 1),
#  (" I am just wondering why you do n't have an option for choosing what amount to pay in automatic payments", None, 1),
#  (' I am left with XXXX bank statement', ' after XXXX years later', 1),
#  (' I am more than happy to pay for the items', None, 1),
#  (' I am not refusing to pay', None, 1),
#  (' I am requesting disclosure of the "" original creditors documentation \'\'', 'Servicemember', 2),
#  (' I am seeking clarification as to how payments are to be handled', None, 1),
#  (' I am still waiting for them to submit the Verification of Mortgage to XXXX. I have been told they can only fax it to me', ' we are trying to make a college decision. I also will stop receiving child support the day he graduates. I do not think Citimortgage has the right to delay the process of the refinance. Their business practices are awful', 1),
#  (' I am trying to figure out what they told me they would not send it to collections and still did. and he responds stating the same thing : "" I will  ... (220 characters truncated) ...  lie about my issue to XXXX. I also complained to XXXX but they have done nothing but say they can only go off of email record and not over the phone', 'Consent provided', 1),
#  (' I am unable to log in and am unable to contact them', None, 1),
#  (' I am very bothered by how XXXX has conducted business', None, 1),
#  (' I and about 10-15 other students sued the XXXX XXXX XXXX XXXX for breach of contract after finding out the XXXX XXXX XXXX XXXX said on average', None, 1),
#  (' I applied for the new card on-line', None, 1),
#  (' I applied to refinance my home loan and my credit score was crucial to obtaining an affordable loan for the next 30 years of my life! After the loan ... (161 characters truncated) ...  score and the debt to income ratio in a big way. I called Citibank XXXX customer service to see what it meant as my online hub showed NO payment due', ' what does that mean? And then was why there was a $ XXXX payment due but my Citibank hub showed no payment due? After much talking she got me togeth ... (28 characters truncated) ... nd I explained they pulled my credit WITHOUT my permission and to listen to my conversations. She tried to get me to the manager but no one picked up', 1),
#  (' I ask numerous of time', None, 1),
#  (' I asked Bank to reimburse me', None, 1),
#  (' I asked XXXX who at the bank makes the decision and he told me the Underwriters at US Bank makes the decisions. I asked him if I could speak with them to find out what factors decided the definitive yes or no to a business loan', None, 1),
#  (' I asked her to spell her name and she said in a very sarcastic way "" XXXX', 'Company believes complaint represents an opportunity for improvement to better serve consumers', 1),
#  (' I asked how to file and was told send a copy to their office', None, 1),
#  (' I asked if she had pulled calls from around that time frame as I had requested. She stated no', 'Consent provided', 1),
#  (' I asked my wife', " I finally got XXXX XXXX on the telephone ; he first stated he could not speak with me because my name was not on the checking account. I reminded hi ... (62 characters truncated) ... ly said he would probably mail it. I told him it was close to XXXX and we needed the check to do what needed to be done. He did n't say anything else", 1),
#  (' I asked them to provide the refinance paperwork ; however', None, 1),
#  (' I attempted to make several arrangements to catch up but fell short. As a result of that', None, 1),
#  (" I become ineligible for a HARP. '' If there is documentation stating the aforementioned quote", None, 1),
#  (' I began receiving calls again from WFDS', None, 1),
#  (' I believe that essential information about simple ground rules of the modification process were kept from me. I also believe that serious delays caused by the bank which inflated the amount of the loan over the years is not being considered by the underwriters. And finally', None, 1),
#  (' I believe this account is invalid because any original creditor that I had a balance with years ago', None, 1),
#  (' I believe this to be an unlawful attempt to extort funds from me', None, 1),
#  (' I called Honda back and asked again for help so I can keep my vehicle', None, 1),
#  (' I called XXXX directly again on XXXX/XXXX/16. I was told voice messages were left notifying me of the late payments', None, 1),
#  (' I called and filed for claim for XXXX out XXXX transactions cleared in bank statement. On XXXX/XXXX/2016', None, 1),
#  (' I called and submitted a call back request. I had to call XXXX additional times time to get a status update. Each time I was given a different time frame for the transaction refund ( XXXX biz days', None, 1),
#  (' I called back at XXXX and told them I have already spoken to them this week and that I will not have a different answer than what I have already giv ... (265 characters truncated) ... redit Services Inc ( XXXX ) @ XXXX I get a call and voicemail from XXXX XXXX at Sunrise Credit Services Inc . I call back @ XXXX and speak with XXXX ', None, 1),
#  (' I called customer service. They were helpful at first ... but promised action which they never delivered. ( For example', None, 1),
#  (' I called the Amazon Credit Card / Synchrony bank and managed to get my account number. While on the phone', None, 1),
#  (' I called them', None, 1),
#  (' I called to inquire about the replacement refund check. I again spoke to XXXX who told me that early in the month', None, 1),
#  (' I called to set up payment arrangements and speedy cash told me my account has went over to a third party collection agency. They also provided me with XXXX. I never provided them with my debit card from XXXX XXXX information. However', None, 1),
#  (' I can call many times if i get a busy or no answer but if I talk to a debtor to make a demand I really should not all XXXX times in a day. If I did not have money at XXXX', None, 1),
#  (' I can not believe that this shift in standards is a misunderstanding or an error made in good faith. When I raised the concern initially', None, 1),
#  (' I can not pay them', None, 1),
#  (' I can only lodge a complaint by phone. To prevent further charges to my account and because of my inability to reach BOA', None, 1),
#  (' I can see that she is only interested in having me pay money', 'First Advantage LNS Inc.', 1),
#  (' I checked in to be sure the miles would be posted as promised', None, 1),
#  (' I checked my FICO score and it was XXXX. Within one week ( today )', None, 2),
#  (' I checked my balance online and saw that all the XXXX transactions were pending', ' and found that the TCF ATM does not take deposits. The nearest branch is XXXX miles from my home', 1),
#  (" I contacted Wells Fargo 's agents advising them of my struggles to keep up with my mortgage payments. Wells Fargo 's agents offered me an opportunit ... (55 characters truncated) ... eparate loan modification packages. After what seemed like the run around and paper chase with agents requesting and re-requesting the same documents", None, 1),
#  (' I contacted customer service again', ' which to date', 1),
#  (' I contacted my bank', ' including a letter from the garage in XXXX that verified the work done in XXXX was not what I requested', 1),
#  (" I contacted the State 's Attorney General 's Office in XXXX", None, 1),
#  (' I continued to pursue my case and finally', ' no one is held accountable for his promise. In fact', 1),
#  (' I could not log on answering the questions as myself. I tried again about XXXX hour later and XXXX of the XXXX questions were geared for my sister in law', ' which is what SHE owns', 1),
#  (' I decided to send money to people on my mailing address for them to send me the card that arrived on XXXX. When they are ready to send', None, 1),
#  (" I demand to see Assignments. A major crime has been committed and It is very Obvious that they 've tried to Manipulate me and the legal System as we ... (84 characters truncated) ... nipulate CFPB as well. These XXXX companies are CRIMINALS and Have Many Fraud Complaints and Lawsuits Filed against them. By checking CFPB site alone", None, 1),
#  (' I did', None, 1),
#  (' I did my due diligence to protect myself and wished that PNC did the same for its cardholder."', 'Web', 1),
#  (' I did my research and found numerous complaints about this company as well as a news piece by investigative reporter "" XXXX XXXX \'\' that aired XXXX 2012 : XXXX"', 'Web', 1),
#  (' I did not feel comfortable. At this point', None, 1),
#  (' I discovered in 2015 that I am the victim of major identity theft. If someone opened up a fraudulent account with CitiBank', None, 1),
#  (" I do n't remember. I complete XXXX loan applications a month ''. At that time", None, 1),
#  (' I do not know what this account is nor did I ever sign any documentation with this company. I have disputed it several times and as you can see the  ... (91 characters truncated) ... ' this issue was never resolved? I received no validation documentation of what this is nor where my signature is nor that this account belongs to me', None, 1),
#  (' I entered my credit card number and it came back to me with', None, 1),
#  (' I eventually conducted a three way phone call with XXXX regional supervisor and a TD Bank supervisor. During the call', None, 1),
#  (' I expect that all adverse information will be withdrawn from the credit records of XXXX XXXX XXXX immediately. In the event such adverse information is not withdrawn', None, 1),
#  (" I expected my PayPal balance to reflect the cancellation quickly. It did n't. I finally got a XXXX rep with enough skills to get me the XXXX phone number and information. The information was that I needed to get PayPal support on the phone and conference in XXXX. XXXX confirmed on the phone", ' not theirs at all."', 1),
#  (' I explained myself again and he said I had the following options and I quote ; "" Make the payment in full', None, 1),
#  (' I explained that I never knew I had a debt and certainly would have worked this out with the hospital', ' I do the same thing', 1),
#  (' I faxed this written statement to the number provided. On XXXX/XXXX/16', None, 1),
#  (' I feel as though XXXX XXXX XXXX', ' have some of my debt removed and my credit cleaned up. I was young', 1),
#  (' I feel it is BAD PRACTICE for Capital One to not put SOMETHING', None, 1),
#  (' I feel like somewhere I received some bad student loan advice and possibly made some errors along the way. XXXX University in XXXX', ' however. The XXXX University Financial Aid Office was horrifically inept and even though I regularly tried to contact them', 1),
#  (' I feel sure this is a scam', None, 1),
#  (" I filed a inquiry to XXXX to clarify what had happened and to ask for a refund. On XXXX/XXXX/16 I received this response : I 'm sorry if the fee was ... (53 characters truncated) ...  certainly research if this is an issue on our end or deluxe. You may return the checks to your nearest branch at usbank.com/locations. In the future", None, 1),
#  (' I finally got a human on the line. She sounded XXXX and did not grasp that this was a fraudulent use of my account until I pointed that out to her. She said she would get the charges removed from my account and would also cancel it', None, 1),
#  (' I finally got the funds on Thursday', None, 1),
#  (' I first purchased my home by signing a home loan with XXXX and was immediately transferred to Wells Fargo Bank. I paid my mortgage as agreed on time for years. However', None, 1),
#  (' I followed further instructions from my supposed new employer to send XXXX wire transfers for {$800.00} and {$900.00} to XXXX', 'CA', 1),
#  (' I forgot to cancel the service prior to it converting into a recurrent billing subscription. After noticing the charges a month or two later I conta ... (138 characters truncated) ... acted them again and when that did not work I closed my bank account and opened a new account to prevent any further unscrupulous charges. Last night', ' requesting a cancellation payments have always stopped so I have never needed to ever call Paypal with a problem. Needless to say', 1),
#  (' I found that Discover had a department called the "" Executive Office of Customer Advocacy. \'\' I thought this dept would handle my concern in a more "" independent \'\' manner', None, 1),
#  (' I found the XXXX XXXX XXXX XXXX \'Welcome Letter \' mixed in with some junk mail that was sitting on my office desk - I was in the process of accumulating various numbers for my XXXX Tax return."', 'Web', 1),
#  (' I got an alert ( Through an ID monitoring service ) that my credit report had a hard inquiry twice', None, 1),
#  (' I guess to prevent customer complaints. And it is not working for many days now', 'Consent provided', 1),
#  (' I had 9 months before that was to begin. RMS has made a complete mess out of this seemingly easy transaction and with no legal oversight by state and federal regulators', None, 1),
#  (' I had approximately 15 months remaining on my business locations lease and certainly informed him of that fact. I also mentioned that I wanted to save approximately XXXX dollars per month with any new agreement', None, 1),
#  (' I had come to find out this had happened again when Sallie Mae was asking for the upcoming XXXX payment. I called Sallie Mae to figure out what was  ... (198 characters truncated) ...  I then asked that enough money be taken out of the overflow account to pay for any outstanding payments ( XXXX and XXXX payments ) for the XXXX loan', None, 1),
#  (' I had defaulted on XXXX my smaller loans. The loan did get paid off but this has effected my credit score as well as my parents and when trying to t ... (308 characters truncated) ... . When asked if the terms could be changed or allowed for my cosigner parents to be released from my loans after so many consecutive on time payments', None, 1),
#  (' I had exceptional credit score', None, 1),
#  (' I had gone into a Chase bank branch and followed instructions to withdraw my cash from my checking/savings account', None, 1),
#  (' I had made XXXX successful payments on time with this current loan', None, 1),
#  (' I had some extraordinarily large bills to pay. Car registration', ' threatening letter from a XXXX XXXX', 1),
#  (" I had to cancel that dispute. It will come out of my account tomorrow and I 'll be negative", None, 1),
#  (' I had to verify the last XXXX of my SS. Then the man ( XXXX XXXX ) said I took out a payday loan in XXXX 2013 from XXXX XXXX', '782XX', 1),
#  (' I have XXXX requests. First', None, 1),
#  (' I have also been inundated with emails from Western Union and others. If I recall', None, 1),
#  (' I have asked among other things in my day XXXX/XXXX/XXXX dispute a copy of the contract signed by my accepting the terms and conditions of these bills and my obligation to pay a bill it is not proof of debt', ' any document without my signature lacks validity', 1),
#  (' I have asked and told them to STOP calling me', None, 1),
#  (' I have asked time and time again for account loan data from original lender and the debt collector refused yet they are continuing to threaten to st ... (98 characters truncated) ... ing further injury to me and my family. Altisource has called me numerous times and has called relatives and discussed with them our private business', 'Consent provided', 1),
#  (' I have been asking for my Mortgage Loan review for the past one year now', None, 1),
#  (' I have been communicating on many occasions about issues with payment transaction issues. Each and every time I have communicated with your organization', None, 1),
#  (" I have been denied access to speak directly to the CITIBANK 'S legal department and have been", None, 1),
#  (' I have been depleting what little retirement I had from my Mutual funds and IRA to be able to meet living expenses. At this rate', None, 1),
#  (" I have been paying extra on my car loan since we purchase the car in XXXX XXXX XXXX XXXX. The question I have is my payment is XXXX and my loan paym ... (296 characters truncated) ...  will credit XXXX out of a payment of XXXX and the answer is they carry that overpayment forward and I ask why do n't they apply some to the interest", None, 1),
#  (' I have cried', None, 1),
#  (' I have enclosed the XXXX Cancelling the debt. Please delete this account XXXX XXXX', None, 1),
#  (' I have finally had an opportunity to speak with XXXX and get to the increase in closing costs. Our initial interview was on XXXX/XXXX/XXXX. At that time I was calculating the Tax Transfer Fee to be a common and customary fee 100 % paid by for by the seller. XX/XX/XXXX', None, 1),
#  (" I have n't received a letter", None, 1),
#  (" I have never been given any kind of credit unless I asked for it and filled out a credit application. How can PayPal be allowed to get away with this scam? I 've been using PayPal for years. If they 've done something to their check out process to make PayPal Credit the default", None, 1),
#  (' I have never heard from any of them. I will attach the docs that show the tax releases. I hope you can help me', None, 1),
#  (' I have no obligation to XXXX since XXXX lnXXXX', ' her pay was reduced. XXXX staff advised that we could restructure the loan slightly so she could make payments. I helped her with several payments as we waited for XXXX to work with us. Rather suddenly', 1),
#  (' I have no other choice that make my complaint more public and request escalation on this case."', 'Web', 1),
#  (' I have proven your records are inaccurate compared to the financial institution transactions', None, 1),
#  (' I have received XXXX calls', None, 1),
#  (' I have received XXXX curb appraisals from Wells Fargo Bank', ' XXXX Wells Fargo sent out a 30 day notice to pay my past due amounts owed', 1),
#  (' I have received over 50 calls from this number XXXX. When I pick up the phone', None, 1),
#  (' I have requested a complete detailed explanation of the current deficiency which has gone unanswered. I believe the current monthly payment is also incorrect and does not reflect the terms in both the Truth in Lending Statement as well as the actual terms of the Adjustable Rate Note."', 'Web', 1),
#  (" I have searched the Federal Housing Administration 's ( FHA ) website", None, 1),
#  (' I have shared my bank statement ( attached ) showing the XXXX {$200.00} transactions and XXXX {$100.00} transactions as well as the recovery of XXXX ... (60 characters truncated) ... t in their system they showed XXXX {$200.00} transactions on XXXX however their system rejected XXXX {$200.00} payment and it went back to the source', None, 1),
#  (" I have since I was XXXX I 'm now XXXX the close of escrow is XXXX - this house was the perfect house for my husband who is XXXX", None, 1),
#  (' I have since put a stop payment on all my automatic-bill transactions', ' when all I had to do was give the bank what I actually owe them', 1),
#  (' I have spoken to several Barclay representatives', None, 1),
#  (' I have submitted information to remove the XXXX addresses that are not associated with me', None, 1),
#  (' I have tried to contact them directly and through the Credit Bureau', None, 1),
#  (' I have tried working out payments with Navient', None, 1),
#  (' I have without fail made monthly and timely in-person payments on both accounts', ' despite verbal confirmation I received from Brown subsequently', 1),
#  (' I headed to a Wells Fargo branch in XXXX XXXX', None, 1),
#  (" I honestly believe Chase 's practice of clearing pending charges at XXXX at night and then having any direct deposit come in shortly after XXXX is an Unfair", None, 1),
#  (' I in no way was expecting to be relieved of my responsibility for the balance', None, 1),
#  (' I just called - and an employee said I needed to talk to someone in customer service. They gave me the telephone number', None, 1),
#  (' I kept getting AUTO GENERATED letters that information was verified with the furnisher thus it should stay on the record. When contacted furnisher-  ... (26 characters truncated) ... alifornia-they confirmed in writing that they DO NOT REPORT OR VALIDATE any information to none of the bureaus ... VERIFICATION BY EXPERIAN WAS A LIE', None, 1),
#  (' I know I qualify for a Loan Modification', None, 1),
#  (' I learned about "" insufficient funds \'\' fees and how those are different than "" overdraft fees \'\'. If you pay some of your monthly bills automatically', None, 1),
#  (' I learned that the mortgage company has had an expired license since 2009. Then I asked the licensed real estate agent who did the paperwork in the  ... (233 characters truncated) ... ts on people. CREDCO has not responded to my email about it. It seems to me that CREDCO should know whether or not its customers are even in business', None, 1),
#  (' I left XXXX yet another voice mail sharing my expectation that the funds were back in my hands by the end of the week. I received neither a response nor the check. When I called today', None, 1),
#  (' I made a purchase in XXXX', None, 1),
#  (' I met with assistant store manager', None, 1),
#  (' I never received any bill for this service until now', None, 1),
#  (' I never received the XX/XX/XXXX statement so no payment was made. When the next statement came it had penalty and interest so i called to find out why and discovered the missing statement', None, 1),
#  (' I overpaid {$200.00} in response to Synchrony \'s demand for {$110.00} to allegedly bring my account "" current', ' Account XXXX', 1),
#  (' I paid the XXXX dollars to get this lifted on XXXX/XXXX/2016 and then they XXXX XXXX can back and said they could run file because I had a federal fraud alert on my phone number. My phone number was not listed in my file', None, 1),
#  (' I pity the less sophisticated', '681XX', 1),
#  (' I provided Experian a copy of a government identification', None, 1),
#  (' I provided the requested information to TSI', None, 1),
#  (' I pulled XXXX and XXXX as well. Sure enough', 'Collections Acquisition Company, Inc.', 1),
#  (' I pulled up my account online and saw that there was a fraudulent hold placed on my account as I was overseas. Called citibank and spoke to different consultants and managers but no ones seems to know how to help me. They ask me for my personal informations like account password', None, 1),
#  (' I put an offer on a house. It was a XXXX foreclosure home owned by the XXXX XXXX. After many transfers of paperwork and paying for home inspections', " there are too many repairs for the bank that is approving your loan to deal with ''. So I lost the house and money I spent on everything to get it approved At that point the vacation rental was already overdue for me to move out", 1),
# ...
#  (' XXXX. The XXXX website says that based on this date', None, 1),
#  (' XXXX. This is to advise you that despite the fact that YOU have received a response from Wells Fargo', ' do you do anything to justify your existance? Do you do any independent investigation of complaints? So in addition to my complaint against Wells Fargo', 1),
#  (" XXXX. XXXX for collections and they could provide no further info and that I 'd have to contact them ( XXXX ). I then made contact with XXXX the same day", ' Contact Us and Profile', 1),
#  (' XXXX/XXXX/16', None, 2),
#  (' XXXX/XXXX/2016', None, 2),
#  (' XXXX/XXXX/XXXX', None, 7),
#  (' XXXX/XXXX/XXXX', 'Company believes it acted appropriately as authorized by contract or law', 1),
#  (' XXXX/XXXX/XXXX and on Saturday', None, 1),
#  (' Your lawyer can request invoices', None, 1),
#  (' a XXXX mortgage', None, 1),
#  (' a banking institution with operations all over the world', None, 1),
#  (' a checked was bounced on me which caused my bank to bounce a check to Citicorp for payment on my credit card. I let them know in advance', None, 1),
#  (" a corrected bill will be sent. '' 4. In a new bill", None, 1),
#  (' a cosigner', None, 1),
#  (' a debt collector shall', ' or any portion thereof', 1),
#  (' a division of Hyundai Capital America ( "" HCA \'\' ) engaged in illegal', None, 1),
#  (' a look at the actual XXXX data provided by the XXXX XXXX XXXX XXXX clearly shows that the XXXX has been *decreasing* since the middle of XXXX', None, 1),
#  (' a money line of credit', None, 1),
#  (' a plummeting credit profile', None, 1),
#  (' a provider of legal services to the mortgage bankingIndustry', None, 1),
#  (' a representative told me that I was eligible for further 2 month forbearance on each loan. I called today to arrange these forbearances', None, 1),
#  (' a service does not have the rights of a holder in due course and therefore', None, 1),
#  (' about a year ago', None, 1),
#  (' access to a computer', None, 1),
#  (' according to internet search ) about unknown person. Nobody at our number ( XXXX ) has any debt and we are on the Do Not Call List. The robo-call leaves a message to call XXXX about XXXX (? ) XXXX (? ) a name we have no knowledge of. The company calls late at night', None, 1),
#  (' account type', None, 1),
#  (' accounts to claim full responsibility on', None, 1),
#  (' actual damages sustained by the consumer as a result of the failure or {$1000.00}', '', 1),
#  (' address', None, 1),
#  (' addresses', None, 1),
#  (' advice of counsel', ' \'\' Wells Fargo stated. "" However', 1),
#  (' after I refused to give my SSN but did give the rep the account number which was on the card', None, 1),
#  (' after along hold the associate told us the deposit transfer would take 2 days not 24hrs', None, 1),
#  (' after making big payments for a few years', None, 1),
#  (" after over two months of discussions -- Citi 's mortgage broker announced that our income was insufficient to qualify for both mortgages at once. ( Not insufficient for either loan", None, 1),
#  (' after reconfirming eligibility and terms via REST Report/Loan Disposition Analysis/NPV', None, 1),
#  (' after repeatedly calling Chase to confirm the payment amount. Thanks to the brilliant idea of a verbal mortgage! Our records also confirm that we first tried to make the second payment on-line but when it was not accepted', None, 1),
#  (' after speaking with XXXX XXXX XXXX ( did not have an offer for the property', None, 1),
#  (' after this Complaint to your agency', None, 1),
#  (' after this payment my account balance became XXXX . At XXXX/XXXX/2016 I called to costumer service by number XXXX', None, 1),
#  (' again', None, 2),
#  (' again this year they always have for the 3 years I have been with them. Ever since I have been with Quicken loans insurance agent has called me conc ... (262 characters truncated) ... s that it has been paid but it has not. One of the employees at QL did pass on to me that they use a 3 rd party vendor to pay all taxes and insurance', None, 1),
#  (' agony and negative reflection this has caused is unacceptable', None, 1),
#  (' all he can do is give me his business card with a note saying he had this discussion with me ; he gave me his card and dated and sign that he had the discussion with me. He then recommended that I go to my Bank', None, 1),
#  (' all individuals named below are CapitalOne employees ) : XXXX XXXX 2016 : I opened a savings account to capitalize on a "" new customer \'\' bonus ( {$500.00} ) advertised as being available 90 days after opening a savings account. I am informed CapitalOne "" prefers \'\' ( i.e.', None, 1),
#  (' all information', None, 1),
#  (' all via phone. Each time', ' but no calculations as to how that amount was determined. So far', 1),
#  (' almost all making serious criticism of HSBC', None, 1),
#  (' along with XXXX that put the pressure on us and refused to speak with me', None, 1),
#  (' along with XXXX {$120.00} late fees. That is wrong', None, 1),
#  (' along with proof of all owners from each subsequent transaction made when the note was packaged and sold and resold to investors who made investment decisions based on the packaged mortgage backed securities being represented to them that there was', None, 1),
#  (' although I was able to get out of my counseling job paying {$13.00} an hour after 12 years of service with that agency', ' I found a roommate to share expenses a month ago', 1),
#  (' although nowhere on the bill does it state that the closing date is the actual date on which the bill is printed. At minimum', None, 1),
#  (' among these account XXXX them was with bank of America. I had immediately contacted the credit bureaus and had notified them about my identity was s ... (317 characters truncated) ... f America that been giving me the run around for the past two and half years. I had send them the following letter certified mail more than ten times', None, 1),
#  (' amount', None, 2),
#  (' an identifier or their last name. However', None, 1),
#  (" an important buyers ' feature in XXXX XXXX XXXX XXXX XXXX ii", None, 1),
#  (' an incomplete account number and many pages of generic documents that did not apply to the case at all. Prior to court', None, 1),
#  (' and', None, 1),
#  (' and Chase the resolved the issue then', None, 1),
#  (' and I am forwarding this information to my Senator XXXX XXXX', None, 1),
#  (' and I believe that the note and security instrument were sold already', None, 1),
#  (' and I demanded my promisary note and proof of payments made since XX/XX/XXXX ( see attached ). AES continued to send me a bunch of nonsense regarding a "" deferment \'\' and a "" forbearance \'\' on my loan ... none of which I initiated. XX/XX/XXXX', None, 1),
#  (" and I faxed her copes of my information. XXXX followed up with XXXX XXXX and the bank 's legal department", ' and still do', 1),
#  (' and I found out that Syndicated Office Systems ( whom also goes by Central Financial Control ) put my account to collection. I called the phone # listed within my credit report', None, 1),
#  (' and I have had a difficult time coming to grips with the result of part of the outcome since. I am an honest hard working person', None, 1),
#  (" and I have recepts of checks that are not listed on payment history that I did n't receive credit for and Ocwen has the proof", None, 1),
#  (" and I was getting help from the bank 's VP. I was telling her about my situation and she suggested that I write you. She told me that you are a nice and understanding man. XXXX XXXX", None, 1),
#  (' and Insurance documents. XXXX providing information that this car is garaged at her home address "" a senior housing complex \'\' XXXX continues to report that I am a cosigner on this account the most compelling evidence', None, 1),
#  (' and SunTrust agreed', ' and landlords may not discriminate on the basis of race and national origin ( the Act also prohibits discrimination based on sex', 1),
#  (' and TransUnion continues to list the disputed item on my credit report I will find it necessary to sue you for actual damages and declaratory relief under the FCRA. According to this regulation', None, 1),
#  (' and TransUnion have come back to me and stated they were able to verify these inaccurate accounts. How is this possible? Under the laws of the FDCPA', None, 1),
#  (' and XXXX as a partial payment toward this month. See other email I sent to your company today for further explanation', None, 1),
#  (' and accecpted by', '', 1),
#  (" and after substantiating borrower 's default and servicer 's right to foreclose. XXXX XXXX b ). They violated the National Mortgage Settlement guidelines XXXX", None, 1),
#  (' and all accounts thereof are accepted for value', None, 1),
#  (' and also found out that XXXX XXXX is not an attorney as he told me he was. This evening', None, 1),
#  (' and also told them to contact the person and get their correct information', None, 1),
#  (' and always have been', None, 1),
#  (' and am not getting anywhere with it. The seller has also quit responding to all of my emails. I am about to close my PayPal account', 'Consent provided', 1),
#  (' and any remaining balance would be forgiven. I did as you asked. It now appears that you have failed', None, 1),
#  (' and being that he is the professional', None, 1),
#  (' and can not according to XXXX - as this data is not expected to be sent by a debt collector on this industry standard file. I have never been late with XXXX nor XXXX 8. XXXX account on EQ is reporting a creditor classification of "" RETAIL \'\' and can not', None, 1),
#  (' and confusion with my transactions. All in which were proven beyond my control', None, 1),
#  (' and during the deferral period before that', None, 1),
#  (' and enter an amount to pay', None, 1),
#  (' and extended family members', None, 1),
#  (" and found many customers have had issues with XXXX XXXX ' not honoring sign-up bonuses", None, 1),
#  (" and frustrating my lawful efforts to close my Father 's accounts. I am hoping CFPB can compel Bank of America to take my concerns seriously", None, 1),
#  (' and had no intention of honoring its agreement. I am aware that Midland records all of its phone calls', 'Consent provided', 1),
#  (' and have added it to my Trans Union and XXXX credit reports as a brand new Unpaid Charge Off Debt', None, 1),
#  (' and have been found that XXXX was one of their biggest profit makers', None, 1),
#  (' and have been told that', None, 1),
#  (' and he assured me they would handle it at XXXX. When I called THAT number', None, 1),
#  (' and how to proceed if you do n\'t think you owe the money. The last option was not give to me. Both companies attempted to hide information from the ... (304 characters truncated) ... ose the account so no one else can attempt to collect the debt in which both companies violated debt collection practices laws and arbitration laws."', 'Web', 1),
#  (' and if she will furnish our office what the dispute is', None, 1),
#  (' and if so', None, 1),
#  (' and if your Agency fails to find probable cause', None, 1),
#  (' and in the order they occurred', None, 1),
#  (' and its Pay Status', 'Consent provided', 1),
#  (' and last', None, 1),
#  (' and let me know. I had no problem getting the same from XXXX and XXXX. Thanks', 'Consent provided', 1),
#  (' and letters', None, 1),
#  (' and many times completely inaccurate information. Aside from the moral obligation', 'Consent provided', 1),
#  (' and marketing loan products to avoid and thereby discourage prospective borrowers in predominantly XXXX and XXXX neighborhoods in at least XXXX Metropolitan areas. Wells Fargo has a history of case management procedures which are wrong and illegal. During the relevant period', None, 1),
#  (' and moneys to purchase property. Realtor representing seller knew that property was not eligible for sale on XXXX XXXX 2016 when listed for sale and on XXXX XXXX', '782XX', 1),
#  (' and my loan payment is still pretty high', None, 1),
#  (' and no results provided. I called the hospital and they had no records of any lab work. The debt was only {$170.00} and now my credit score has take ... (107 characters truncated) ...  into it. I was unaware they reported it because other than the second letter they sent me which only contained a print out of medical coding screens', None, 1),
#  (' and not Current in its PAY STATUS 3. This account is missing Pay History 4. This account is missing Balance History 5. Please validate this account', 'Consent provided', 1),
#  (' and not serve the public."', 'Web', 1),
#  (' and noticed that Chase made incorrect calculations. On the application', None, 1),
#  (' and now they just filed a judgement of debt for {$220.00}', None, 1),
#  (' and on page XXXX', None, 1),
#  (' and once again we did not receive a detailed reason for the denial', None, 1),
#  (' and only received XXXX TPP under HAMP. He further meets all basic criteria for HAMP eligibility as outlined in section XXXX', None, 1),
#  (' and other information incorrect in my IDENTIFICATION VERIFICATION."', 'Web', 1),
#  (' and please correct the Activity designator to "" CLOSED \'\' - Willfully violate obligations under the FCRA', '', 1),
#  (" and prevent me from paying it off early. Why would an account like 'unapplied amount ' even exist? Except to criminally hold my money", None, 1),
#  (' and protect consumers from this predatory abuse', None, 1),
#  (' and requested an appeal or other process to reduce what I am being told is a mandatory minimum payment to "" Rehabilitate \'\' the Loan. The student loan manager emailed me back stating that the collection agency is correct', None, 1),
#  (' and seems to be a matter of unfair', None, 1),
#  (' and she said it takes 10 business day for a reply to be generated - it would have been nice if the person that answered my first call would have said that', None, 1),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 13 y ... (16 characters truncated) ...  no Balance History in this account - and there should be as this account was opened for over 13 years 4. Because this account has no Payment History', None, 2),
#  (' and should be "" Revolving/Option \'\' 2. There is no Payment History in this account - and there should be as this account was opened for over 3 ye ... (14 characters truncated) ... s no Balance History in this account - and there should be as this account was opened for over 3 years 4. Because this account has no Payment History', None, 3),
#  (' and since then I have been unable to find any. I am living with my mother for the first time in a decade', None, 1),
#  (' and spoke and received letters from BOA executive office and NO ONE offered me the core account. NO ONE! This would have been a very easy fix as I already had direct deposit anyway!!! I am so mad that all I received was explanations and copies of my CM agreement', ' commended for great customer service and some knowledge about the accounts. Maybe she should be in the executive office! Please', 1),
#  (' and spoke to XXXX ( Customer Service Agent ) who completely refused to help. I then asked to speak to a supervisor', None, 1),
#  (' and still', None, 1),
#  (' and still be able to provide the beneficiary with a XXXX repayment', None, 1),
#  (' and temperatures in the XXXX', ' and found someone with a truck to tow me into town. One week later I was able to charter a flatbed truck passing down the road on its way to XXXX', 1),
#  (' and that I had no reason to anticipate such blatant disregard for my time and situation. Travel plans have had to be postponed due to these unjustified delays', ' but merely designed to take advantage of their customers during a time when cooperation from their lender is most needed. It is a shameful and demeaning way to operate a business."', 1),
#  (' and that I need to pay in order for them to do anything', 'Consent provided', 1),
#  (' and that his communication was an attempt to collect a debt', None, 1),
#  (' and that is NOT LAWFUL! I have no proof', None, 1),
#  ...]

# %% [markdown]
# ### (d) EXPLAIN (5 puntos)
#
# Investigue y utilice la versión SQLite de EXPLAIN para mostrar que SQLite reconoció y está utilizando su _covering index_.
#
# La sintaxis va algo así:
#
# > EXPLAIN QUERY PLAN your_query_here;

# %%
# %%sql
#
# -- Inserte su query aqui

# %% [markdown]
# Ejercicio 2
# =========
#
# Ahora veamos cómo aplicar estos conceptos a una base de datos un poco más pesada.
#
# Cargue a continuación la base de datos **ontime-2017-2018.db** utilizada durante su proyecto 1.
#
# Recuerde que puede consultar los detalles de los atributos [aqui](https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236).

# %%
# %sql sqlite:///ontime-2017-2018.db

# %% [markdown]
# Escriba a continuación el query necesario para mostrar los índices existentes en esta base de datos:

# %%
# %sql -- Inserte su query aquí

# %% [markdown]
# ### (a) Uso de índices en Flights (20 puntos)
#
# Ahora considere el siguiente query:
#
# ```
# SELECT f.dest
# FROM ontime f
# GROUP BY f.dest
# ```
#
# Haga uso de EXPLAIN QUERY PLAN y de `%time` para mostrar, utilizando múltiples celdas, la diferencia en el tiempo de respuesta cuando existe un índice sobre `ontime.dest`.
#
# _Nota_: Para responder a este ejercicio deberá eliminar el índice creado sobre este campo. Es probable que luego deba reiniciar la el kernel del Juyper notebook para lograr que el query plan ya no muestre al índice eliminado.

# %% [markdown]
# ### (b) Uso de covering indexes (20 puntos)
#
# El siguiente query reporta el promedio de retraso en el tiempo de llegada por cada aerolínea que vuela hacia el aeropuerto JFK:
#
# ```
# SELECT a.description, AVG(f.ArrDelay) as ArrDelayAverage
# FROM ontime f
#     LEFT JOIN unique_carriers a ON f.reporting_airline = a.code
# WHERE a.code IN (
#     SELECT DISTINCT f2.reporting_airline
#     FROM ontime f2
#     WHERE f2.dest = 'JFK'
# )
# GROUP BY a.description
# ORDER BY ArrDelayAverage DESC;
# ```
#
# Defina un covering index que mejore el desempeño del query, y muestre la respectiva mejora:

# %% [markdown]
# ### (c) Optimización de queries del proyecto (30 puntos)
#
# Utilizando las herramientas aprendidas durante este laboratorio mejore el tiempo dejecución de uno de los queries propuestos para su proyecto 1, o justique por qué no es posible mejorar ese tiempo de respuesta agregando nuevos índices.
